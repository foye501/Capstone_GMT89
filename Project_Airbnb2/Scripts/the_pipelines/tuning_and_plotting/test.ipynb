# %%
import pandas as pd
import numpy as np
import openpyxl
import re
from re import sub
from decimal import Decimal
import time
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from numpy import unique, where
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
from sklearn.metrics import r2_score, silhouette_samples, silhouette_score , completeness_score , homogeneity_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from IPython.display import display, HTML, display_html
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# %%
from Generating_Feature_Importance_tuning_PCA_model import PCA_My_Airbnb_Capstone_Model, PCA_pre_processing_pipeline
from Generating_Feature_Importance_tuning_raw_feature_model import My_Airbnb_Capstone_Model, pre_processing_pipeline
from scipy.stats import spearmanr
def spearmanr_score(truth, pred):
        return spearmanr(truth, pred)[0]
model = pickle.load(open('./Feature_Importance_tuning_raw_feature_model.pkl','rb'))

# %%
model.grid_search_dict[0.5].best_params_
# Out:
# {'model__learning_rate': 0.2, 'model__max_depth': 11, 'model__num_leaves': 60}

# %%
feature_importance_dict = {}
for q in list(model.grid_search_dict.keys()):
    feature_importance_dict[q] = sorted(dict(
        zip(
            model.grid_search_dict[q].best_estimator_['model'].feature_name_,
            model.grid_search_dict[q].best_estimator_['model'].feature_importances_
        )
    ).items(),
        key=lambda x:-x[1])

# %%
feature_importance_dict
# Out:
# {0.05: [('Location_mean_area_accommodates_price', 87),
#   ('Amenities_amenities_count', 73),
#   ('Amenities_minimum_nights', 70),
#   ('Amenities_property_type_code', 61),
#   ('Amenities_bathrooms_count', 36),
#   ('Location_mean_area_beds_price', 32),
#   ('Amenities_maximum_nights', 30),
#   ('Amenities_room_type_code', 28),
#   ('NLP_관광을_원하시면_믿을수있는_여행사를', 27),
#   ('Amenities_bedrooms', 23),
#   ('Amenities_beds', 20),
#   ('Location_transport_most_close_dis', 19),
#   ('Location_real_estate', 19),
#   ('Location_Los_Angeles_International_Airport', 18),
#   ('NLP_s163', 16),
#   ('NLP_s0', 15),
#   ('Amenities_pool', 14),
#   ('Location_Angeles_Stadium', 14),
#   ('NLP_s23', 14),
#   ('NLP_s196', 14),
#   ('NLP_s232', 14),
#   ('NLP_s250', 14),
#   ('Amenities_bathrooms_type_code', 13),
#   ('Location_transport_1000m_num', 13),
#   ('Location_Santa_Monica_Pier', 13),
#   ('Location_Dodgers_Stadium', 13),
#   ('NLP_하실수', 13),
#   ('NLP_s182', 13),
#   ('NLP_s204', 13),
#   ('NLP_s16', 12),
#   ('NLP_s180', 12),
#   ('NLP_s268', 12),
#   ('NLP_s274', 12),
#   ('NLP_s316', 12),
#   ('NLP_s355', 12),
#   ('Location_Norton_Simon_Museum', 11),
#   ('NLP_s1', 11),
#   ('NLP_s33', 11),
#   ('NLP_s93', 11),
#   ('NLP_s94', 11),
#   ('NLP_s134', 11),
#   ('NLP_s135', 11),
#   ('NLP_s211', 11),
#   ('NLP_s240', 11),
#   ('NLP_s287', 11),
#   ('NLP_s311', 11),
#   ('NLP_s330', 11),
#   ('NLP_s332', 11),
#   ('Location_Universal_Studios_Hollywood', 10),
#   ('Location_Venice_Beach', 10),
#   ('Location_Santa_Monica_Promenade', 10),
#   ('NLP_s12', 10),
#   ('NLP_s43', 10),
#   ('NLP_s55', 10),
#   ('NLP_s60', 10),
#   ('NLP_s75', 10),
#   ('NLP_s158', 10),
#   ('NLP_s306', 10),
#   ('Image_bbf1', 10),
#   ('NLP_s3', 9),
#   ('NLP_s9', 9),
#   ('NLP_s11', 9),
#   ('NLP_s113', 9),
#   ('NLP_s141', 9),
#   ('NLP_s167', 9),
#   ('NLP_s171', 9),
#   ('NLP_s218', 9),
#   ('NLP_s219', 9),
#   ('NLP_s270', 9),
#   ('NLP_s333', 9),
#   ('NLP_s335', 9),
#   ('NLP_s341', 9),
#   ('NLP_s352', 9),
#   ('NLP_s356', 9),
#   ('NLP_s357', 9),
#   ('Image_hist75', 9),
#   ('Image_hist157', 9),
#   ('Amenities_books_and_reading_material', 8),
#   ('Amenities_fire_extinguisher', 8),
#   ('Amenities_microwave', 8),
#   ('Amenities_self_check-in', 8),
#   ('Location_restaurant_num', 8),
#   ('Location_transport_500m_num', 8),
#   ('Location_Griffith_Observatory', 8),
#   ('NLP_boutique_hostel', 8),
#   ('NLP_s13', 8),
#   ('NLP_s25', 8),
#   ('NLP_s51', 8),
#   ('NLP_s53', 8),
#   ('NLP_s74', 8),
#   ('NLP_s76', 8),
#   ('NLP_s79', 8),
#   ('NLP_s175', 8),
#   ('NLP_s176', 8),
#   ('NLP_s189', 8),
#   ('NLP_s212', 8),
#   ('NLP_s220', 8),
#   ('NLP_s225', 8),
#   ('NLP_s263', 8),
#   ('NLP_s275', 8),
#   ('NLP_s278', 8),
#   ('NLP_s285', 8),
#   ('NLP_s318', 8),
#   ('NLP_s337', 8),
#   ('NLP_s343', 8),
#   ('Image_sharpness', 8),
#   ('Image_hist9', 8),
#   ('Image_hist10', 8),
#   ('Image_hist74', 8),
#   ('Amenities_elevator', 7),
#   ('Amenities_pets_allowed', 7),
#   ('Location_cafe_500m_dis', 7),
#   ('Location_Hollywood_Walk_of_Fame', 7),
#   ('NLP_s20', 7),
#   ('NLP_s24', 7),
#   ('NLP_s34', 7),
#   ('NLP_s39', 7),
#   ('NLP_s49', 7),
#   ('NLP_s52', 7),
#   ('NLP_s54', 7),
#   ('NLP_s72', 7),
#   ('NLP_s80', 7),
#   ('NLP_s81', 7),
#   ('NLP_s82', 7),
#   ('NLP_s96', 7),
#   ('NLP_s100', 7),
#   ('NLP_s104', 7),
#   ('NLP_s125', 7),
#   ('NLP_s127', 7),
#   ('NLP_s128', 7),
#   ('NLP_s143', 7),
#   ('NLP_s144', 7),
#   ('NLP_s159', 7),
#   ('NLP_s164', 7),
#   ('NLP_s191', 7),
#   ('NLP_s203', 7),
#   ('NLP_s228', 7),
#   ('NLP_s233', 7),
#   ('NLP_s253', 7),
#   ('NLP_s261', 7),
#   ('NLP_s289', 7),
#   ('NLP_s292', 7),
#   ('NLP_s313', 7),
#   ('NLP_s322', 7),
#   ('NLP_s353', 7),
#   ('Image_hist1', 7),
#   ('Image_hist311', 7),
#   ('Image_hist312', 7),
#   ('Image_hist430', 7),
#   ('Image_mean_mean_min_dist_r3', 7),
#   ('Amenities_bbq_grill', 6),
#   ('Amenities_stove', 6),
#   ('Amenities_tv', 6),
#   ('Amenities_wifi', 6),
#   ('Location_California_Science_Center', 6),
#   ('NLP_sawtelle_boulevard', 6),
#   ('NLP_s2', 6),
#   ('NLP_s7', 6),
#   ('NLP_s19', 6),
#   ('NLP_s41', 6),
#   ('NLP_s45', 6),
#   ('NLP_s58', 6),
#   ('NLP_s88', 6),
#   ('NLP_s109', 6),
#   ('NLP_s115', 6),
#   ('NLP_s126', 6),
#   ('NLP_s139', 6),
#   ('NLP_s142', 6),
#   ('NLP_s149', 6),
#   ('NLP_s162', 6),
#   ('NLP_s173', 6),
#   ('NLP_s184', 6),
#   ('NLP_s188', 6),
#   ('NLP_s194', 6),
#   ('NLP_s198', 6),
#   ('NLP_s201', 6),
#   ('NLP_s205', 6),
#   ('NLP_s223', 6),
#   ('NLP_s227', 6),
#   ('NLP_s244', 6),
#   ('NLP_s254', 6),
#   ('NLP_s273', 6),
#   ('NLP_s286', 6),
#   ('NLP_s293', 6),
#   ('NLP_s295', 6),
#   ('NLP_s300', 6),
#   ('NLP_s307', 6),
#   ('NLP_s309', 6),
#   ('NLP_s315', 6),
#   ('NLP_s329', 6),
#   ('NLP_s338', 6),
#   ('NLP_s339', 6),
#   ('NLP_s367', 6),
#   ('NLP_s369', 6),
#   ('NLP_s376', 6),
#   ('NLP_s381', 6),
#   ('Image_bbf9', 6),
#   ('Image_size', 6),
#   ('Image_contrast', 6),
#   ('Image_dissimilarity', 6),
#   ('Image_homogeneity', 6),
#   ('Image_hist2', 6),
#   ('Image_hist138', 6),
#   ('Image_hist292', 6),
#   ('Image_hist503', 6),
#   ('Amenities_air_conditioning', 5),
#   ('Amenities_cooking_basics', 5),
#   ('Amenities_dedicated_workspace', 5),
#   ('Amenities_free_parking_on_premises', 5),
#   ('Location_supermarket_num', 5),
#   ('Location_Melrose_Avenue', 5),
#   ('Location_Abbot_Kinney_Blvd', 5),
#   ('NLP_smart_tv.', 5),
#   ('NLP_s17', 5),
#   ('NLP_s18', 5),
#   ('NLP_s21', 5),
#   ('NLP_s30', 5),
#   ('NLP_s31', 5),
#   ('NLP_s36', 5),
#   ('NLP_s38', 5),
#   ('NLP_s50', 5),
#   ('NLP_s56', 5),
#   ('NLP_s67', 5),
#   ('NLP_s83', 5),
#   ('NLP_s85', 5),
#   ('NLP_s87', 5),
#   ('NLP_s91', 5),
#   ('NLP_s97', 5),
#   ('NLP_s99', 5),
#   ('NLP_s106', 5),
#   ('NLP_s116', 5),
#   ('NLP_s119', 5),
#   ('NLP_s138', 5),
#   ('NLP_s140', 5),
#   ('NLP_s145', 5),
#   ('NLP_s146', 5),
#   ('NLP_s147', 5),
#   ('NLP_s150', 5),
#   ('NLP_s151', 5),
#   ('NLP_s156', 5),
#   ('NLP_s157', 5),
#   ('NLP_s170', 5),
#   ('NLP_s172', 5),
#   ('NLP_s178', 5),
#   ('NLP_s185', 5),
#   ('NLP_s186', 5),
#   ('NLP_s187', 5),
#   ('NLP_s193', 5),
#   ('NLP_s200', 5),
#   ('NLP_s215', 5),
#   ('NLP_s231', 5),
#   ('NLP_s243', 5),
#   ('NLP_s252', 5),
#   ('NLP_s256', 5),
#   ('NLP_s259', 5),
#   ('NLP_s260', 5),
#   ('NLP_s284', 5),
#   ('NLP_s299', 5),
#   ('NLP_s304', 5),
#   ('NLP_s305', 5),
#   ('NLP_s321', 5),
#   ('NLP_s325', 5),
#   ('NLP_s328', 5),
#   ('NLP_s345', 5),
#   ('NLP_s361', 5),
#   ('NLP_s377', 5),
#   ('NLP_s383', 5),
#   ('Image_correlation', 5),
#   ('Image_hist73', 5),
#   ('Image_hist83', 5),
#   ('Image_hist130', 5),
#   ('Image_hist155', 5),
#   ('Image_hist191', 5),
#   ('Image_hist237', 5),
#   ('Image_hist302', 5),
#   ('Image_hist363', 5),
#   ('Image_hist448', 5),
#   ('Image_hist494', 5),
#   ('Image_hist495', 5),
#   ('Image_hist499', 5),
#   ('Image_hist502', 5),
#   ('Amenities_central_air_conditioning', 4),
#   ('Amenities_coffee', 4),
#   ('Amenities_dishwasher', 4),
#   ('Amenities_exercise_equipment', 4),
#   ('Amenities_indoor_fireplace', 4),
#   ('Amenities_iron', 4),
#   ('Amenities_outdoor_dining_area', 4),
#   ('Amenities_paid_parking_on_premises', 4),
#   ('Amenities_wine_glasses', 4),
#   ('NLP_amc', 4),
#   ('NLP_disneyland.', 4),
#   ('NLP_the_chinese_theater', 4),
#   ('NLP_s4', 4),
#   ('NLP_s8', 4),
#   ('NLP_s10', 4),
#   ('NLP_s15', 4),
#   ('NLP_s27', 4),
#   ('NLP_s35', 4),
#   ('NLP_s37', 4),
#   ('NLP_s46', 4),
#   ('NLP_s47', 4),
#   ('NLP_s48', 4),
#   ('NLP_s57', 4),
#   ('NLP_s59', 4),
#   ('NLP_s64', 4),
#   ('NLP_s65', 4),
#   ('NLP_s66', 4),
#   ('NLP_s68', 4),
#   ('NLP_s86', 4),
#   ('NLP_s90', 4),
#   ('NLP_s92', 4),
#   ('NLP_s95', 4),
#   ('NLP_s107', 4),
#   ('NLP_s108', 4),
#   ('NLP_s118', 4),
#   ('NLP_s148', 4),
#   ('NLP_s155', 4),
#   ('NLP_s161', 4),
#   ('NLP_s169', 4),
#   ('NLP_s174', 4),
#   ('NLP_s199', 4),
#   ('NLP_s206', 4),
#   ('NLP_s208', 4),
#   ('NLP_s209', 4),
#   ('NLP_s213', 4),
#   ('NLP_s217', 4),
#   ('NLP_s221', 4),
#   ('NLP_s234', 4),
#   ('NLP_s239', 4),
#   ('NLP_s241', 4),
#   ('NLP_s247', 4),
#   ('NLP_s248', 4),
#   ('NLP_s251', 4),
#   ('NLP_s262', 4),
#   ('NLP_s265', 4),
#   ('NLP_s266', 4),
#   ('NLP_s267', 4),
#   ('NLP_s277', 4),
#   ('NLP_s291', 4),
#   ('NLP_s312', 4),
#   ('NLP_s317', 4),
#   ('NLP_s319', 4),
#   ('NLP_s340', 4),
#   ('NLP_s344', 4),
#   ('NLP_s351', 4),
#   ('NLP_s359', 4),
#   ('NLP_s366', 4),
#   ('NLP_s368', 4),
#   ('NLP_s373', 4),
#   ('NLP_s378', 4),
#   ('NLP_s379', 4),
#   ('Image_energy', 4),
#   ('Image_hist13', 4),
#   ('Image_hist56', 4),
#   ('Image_hist84', 4),
#   ('Image_hist92', 4),
#   ('Image_hist141', 4),
#   ('Image_hist212', 4),
#   ('Image_hist214', 4),
#   ('Image_hist228', 4),
#   ('Image_hist229', 4),
#   ('Image_hist266', 4),
#   ('Image_hist277', 4),
#   ('Image_hist285', 4),
#   ('Image_hist316', 4),
#   ('Image_hist368', 4),
#   ('Image_hist376', 4),
#   ('Image_hist383', 4),
#   ('Image_hist431', 4),
#   ('Image_hist504', 4),
#   ('Image_hist507', 4),
#   ('Image_oven', 4),
#   ('Amenities_cleaning_products', 3),
#   ('Amenities_essentials', 3),
#   ('Amenities_first_aid_kit', 3),
#   ('Amenities_free_street_parking', 3),
#   ('Amenities_gym', 3),
#   ('Amenities_heating', 3),
#   ('Amenities_hot_tub', 3),
#   ('Amenities_kitchen', 3),
#   ('Amenities_mini_fridge', 3),
#   ('Amenities_refrigerator', 3),
#   ('Location_Farmers_Market', 3),
#   ('NLP_lounge', 3),
#   ('NLP_mini', 3),
#   ('NLP_san_gabriel_mountain', 3),
#   ('NLP_s5', 3),
#   ('NLP_s28', 3),
#   ('NLP_s29', 3),
#   ('NLP_s40', 3),
#   ('NLP_s42', 3),
#   ('NLP_s44', 3),
#   ('NLP_s63', 3),
#   ('NLP_s69', 3),
#   ('NLP_s71', 3),
#   ('NLP_s73', 3),
#   ('NLP_s77', 3),
#   ('NLP_s78', 3),
#   ('NLP_s84', 3),
#   ('NLP_s98', 3),
#   ('NLP_s101', 3),
#   ('NLP_s103', 3),
#   ('NLP_s105', 3),
#   ('NLP_s110', 3),
#   ('NLP_s111', 3),
#   ('NLP_s114', 3),
#   ('NLP_s121', 3),
#   ('NLP_s122', 3),
#   ('NLP_s124', 3),
#   ('NLP_s131', 3),
#   ('NLP_s152', 3),
#   ('NLP_s154', 3),
#   ('NLP_s160', 3),
#   ('NLP_s165', 3),
#   ('NLP_s179', 3),
#   ('NLP_s181', 3),
#   ('NLP_s183', 3),
#   ('NLP_s192', 3),
#   ('NLP_s197', 3),
#   ('NLP_s202', 3),
#   ('NLP_s210', 3),
#   ('NLP_s214', 3),
#   ('NLP_s235', 3),
#   ('NLP_s255', 3),
#   ('NLP_s257', 3),
#   ('NLP_s258', 3),
#   ('NLP_s264', 3),
#   ('NLP_s269', 3),
#   ('NLP_s271', 3),
#   ('NLP_s279', 3),
#   ('NLP_s282', 3),
#   ('NLP_s283', 3),
#   ('NLP_s288', 3),
#   ('NLP_s294', 3),
#   ('NLP_s320', 3),
#   ('NLP_s323', 3),
#   ('NLP_s326', 3),
#   ('NLP_s346', 3),
#   ('NLP_s348', 3),
#   ('NLP_s349', 3),
#   ('NLP_s363', 3),
#   ('Image_bbf4', 3),
#   ('Image_num_contours', 3),
#   ('Image_num_edges', 3),
#   ('Image_hist4', 3),
#   ('Image_hist19', 3),
#   ('Image_hist68', 3),
#   ('Image_hist76', 3),
#   ('Image_hist82', 3),
#   ('Image_hist110', 3),
#   ('Image_hist125', 3),
#   ('Image_hist137', 3),
#   ('Image_hist166', 3),
#   ('Image_hist175', 3),
#   ('Image_hist179', 3),
#   ('Image_hist199', 3),
#   ('Image_hist207', 3),
#   ('Image_hist238', 3),
#   ('Image_hist240', 3),
#   ('Image_hist243', 3),
#   ('Image_hist294', 3),
#   ('Image_hist299', 3),
#   ('Image_hist319', 3),
#   ('Image_hist345', 3),
#   ('Image_hist366', 3),
#   ('Image_hist375', 3),
#   ('Image_hist419', 3),
#   ('Image_hist421', 3),
#   ('Image_hist432', 3),
#   ('Image_hist439', 3),
#   ('Image_hist446', 3),
#   ('Image_person', 3),
#   ('Amenities_baby_monitor', 2),
#   ('Amenities_baby_safety_gates', 2),
#   ('Amenities_bathroom_essentials', 2),
#   ('Amenities_bed_linens', 2),
#   ('Amenities_blender', 2),
#   ('Amenities_carbon_monoxide_alarm', 2),
#   ('Amenities_coffee_maker', 2),
#   ('Amenities_extra_pillows_and_blankets', 2),
#   ('Amenities_fire_pit', 2),
#   ('Amenities_hair_dryer', 2),
#   ('Amenities_hammock', 2),
#   ('Amenities_hot_water', 2),
#   ('Amenities_lock_on_bedroom_door', 2),
#   ('Amenities_oven', 2),
#   ('Amenities_private_entrance', 2),
#   ('Amenities_private_hot_tub', 2),
#   ('Amenities_sun_loungers', 2),
#   ('Location_TCL_Chinese_Theatre', 2),
#   ('Location_Little_Tokyo', 2),
#   ('Location_ACMA', 2),
#   ('Location_Rodeo_Drive', 2),
#   ('NLP_101', 2),
#   ('NLP_apple_tv', 2),
#   ('NLP_brand', 2),
#   ('NLP_home', 2),
#   ('NLP_linen', 2),
#   ('NLP_roku', 2),
#   ('NLP_sofi', 2),
#   ('NLP_studio', 2),
#   ('NLP_sunset', 2),
#   ('NLP_sunset_blvd', 2),
#   ('NLP_the_arts_district', 2),
#   ('NLP_s14', 2),
#   ('NLP_s22', 2),
#   ('NLP_s32', 2),
#   ('NLP_s61', 2),
#   ('NLP_s70', 2),
#   ('NLP_s89', 2),
#   ('NLP_s102', 2),
#   ('NLP_s129', 2),
#   ('NLP_s130', 2),
#   ('NLP_s132', 2),
#   ('NLP_s133', 2),
#   ('NLP_s136', 2),
#   ('NLP_s166', 2),
#   ('NLP_s177', 2),
#   ('NLP_s190', 2),
#   ('NLP_s195', 2),
#   ('NLP_s207', 2),
#   ('NLP_s222', 2),
#   ('NLP_s224', 2),
#   ('NLP_s230', 2),
#   ('NLP_s238', 2),
#   ('NLP_s246', 2),
#   ('NLP_s249', 2),
#   ('NLP_s280', 2),
#   ('NLP_s281', 2),
#   ('NLP_s296', 2),
#   ('NLP_s297', 2),
#   ('NLP_s303', 2),
#   ('NLP_s314', 2),
#   ('NLP_s324', 2),
#   ('NLP_s327', 2),
#   ('NLP_s331', 2),
#   ('NLP_s334', 2),
#   ('NLP_s336', 2),
#   ('NLP_s342', 2),
#   ('NLP_s358', 2),
#   ('NLP_s362', 2),
#   ('NLP_s365', 2),
#   ('NLP_s372', 2),
#   ('NLP_s374', 2),
#   ('Image_bbf7', 2),
#   ('Image_hist3', 2),
#   ('Image_hist5', 2),
#   ('Image_hist11', 2),
#   ('Image_hist18', 2),
#   ('Image_hist25', 2),
#   ('Image_hist33', 2),
#   ('Image_hist39', 2),
#   ('Image_hist47', 2),
#   ('Image_hist65', 2),
#   ('Image_hist70', 2),
#   ('Image_hist71', 2),
#   ('Image_hist77', 2),
#   ('Image_hist88', 2),
#   ('Image_hist89', 2),
#   ('Image_hist94', 2),
#   ('Image_hist102', 2),
#   ('Image_hist103', 2),
#   ('Image_hist104', 2),
#   ('Image_hist119', 2),
#   ('Image_hist126', 2),
#   ('Image_hist127', 2),
#   ('Image_hist128', 2),
#   ('Image_hist136', 2),
#   ('Image_hist140', 2),
#   ('Image_hist143', 2),
#   ('Image_hist148', 2),
#   ('Image_hist156', 2),
#   ('Image_hist167', 2),
#   ('Image_hist182', 2),
#   ('Image_hist183', 2),
#   ('Image_hist185', 2),
#   ('Image_hist188', 2),
#   ('Image_hist190', 2),
#   ('Image_hist196', 2),
#   ('Image_hist202', 2),
#   ('Image_hist211', 2),
#   ('Image_hist213', 2),
#   ('Image_hist216', 2),
#   ('Image_hist217', 2),
#   ('Image_hist219', 2),
#   ('Image_hist221', 2),
#   ('Image_hist230', 2),
#   ('Image_hist232', 2),
#   ('Image_hist251', 2),
#   ('Image_hist253', 2),
#   ('Image_hist258', 2),
#   ('Image_hist261', 2),
#   ('Image_hist273', 2),
#   ('Image_hist274', 2),
#   ('Image_hist276', 2),
#   ('Image_hist278', 2),
#   ('Image_hist281', 2),
#   ('Image_hist283', 2),
#   ('Image_hist284', 2),
#   ('Image_hist287', 2),
#   ('Image_hist289', 2),
#   ('Image_hist290', 2),
#   ('Image_hist291', 2),
#   ('Image_hist295', 2),
#   ('Image_hist300', 2),
#   ('Image_hist301', 2),
#   ('Image_hist303', 2),
#   ('Image_hist321', 2),
#   ('Image_hist347', 2),
#   ('Image_hist348', 2),
#   ('Image_hist355', 2),
#   ('Image_hist358', 2),
#   ('Image_hist364', 2),
#   ('Image_hist373', 2),
#   ('Image_hist374', 2),
#   ('Image_hist393', 2),
#   ('Image_hist403', 2),
#   ('Image_hist408', 2),
#   ('Image_hist409', 2),
#   ('Image_hist418', 2),
#   ('Image_hist422', 2),
#   ('Image_hist427', 2),
#   ('Image_hist429', 2),
#   ('Image_hist435', 2),
#   ('Image_hist440', 2),
#   ('Image_hist444', 2),
#   ('Image_hist459', 2),
#   ('Image_hist471', 2),
#   ('Image_hist475', 2),
#   ('Image_hist476', 2),
#   ('Image_hist483', 2),
#   ('Image_hist485', 2),
#   ('Image_hist486', 2),
#   ('Image_hist508', 2),
#   ('Image_hist509', 2),
#   ('Image_hist510', 2),
#   ('Image_hist511', 2),
#   ('Image_clock', 2),
#   ('Image_mean_mean_weighted_min_dist_r3', 2),
#   ('Amenities_beach_view', 1),
#   ('Amenities_board_games', 1),
#   ('Amenities_body_soap', 1),
#   ('Amenities_bread_maker', 1),
#   ('Amenities_breakfast', 1),
#   ('Amenities_dining_table', 1),
#   ('Amenities_ev_charger', 1),
#   ('Amenities_freezer', 1),
#   ('Amenities_hot_water_kettle', 1),
#   ('Amenities_lake_access', 1),
#   ('Amenities_lockbox', 1),
#   ('Amenities_mosquito_net', 1),
#   ('Amenities_mountain_view', 1),
#   ('Amenities_outdoor_furniture', 1),
#   ('Amenities_outdoor_shower', 1),
#   ('Amenities_patio_or_balcony', 1),
#   ('Amenities_record_player', 1),
#   ('Amenities_shared_pool', 1),
#   ('Amenities_shower_gel', 1),
#   ('Amenities_single_level_home', 1),
#   ('Amenities_smart_lock', 1),
#   ('Amenities_sound_system', 1),
#   ('Amenities_table_corner_guards', 1),
#   ('Amenities_washer', 1),
#   ('NLP_amazon', 1),
#   ('NLP_arts_district', 1),
#   ('NLP_berry_farm', 1),
#   ('NLP_cable', 1),
#   ('NLP_dodger_stadium', 1),
#   ('NLP_hulu_&_disney+', 1),
#   ('NLP_paramount_studio', 1),
#   ('NLP_roku_tv', 1),
#   ('NLP_runyon_canyon', 1),
#   ("NLP_smart_tv'", 1),
#   ('NLP_tcl_chinese_theater_&_dolby_theater', 1),
#   ('NLP_the_long_beach_convention_center', 1),
#   ('NLP_westfield_mall', 1),
#   ('NLP_wi-fi', 1),
#   ('NLP_s6', 1),
#   ('NLP_s26', 1),
#   ('NLP_s112', 1),
#   ('NLP_s117', 1),
#   ('NLP_s120', 1),
#   ('NLP_s123', 1),
#   ('NLP_s137', 1),
#   ('NLP_s153', 1),
#   ('NLP_s168', 1),
#   ('NLP_s216', 1),
#   ('NLP_s226', 1),
#   ('NLP_s229', 1),
#   ('NLP_s237', 1),
#   ('NLP_s242', 1),
#   ('NLP_s245', 1),
#   ('NLP_s272', 1),
#   ('NLP_s276', 1),
#   ('NLP_s290', 1),
#   ('NLP_s298', 1),
#   ('NLP_s302', 1),
#   ('NLP_s308', 1),
#   ('NLP_s350', 1),
#   ('NLP_s354', 1),
#   ('NLP_s360', 1),
#   ('NLP_s364', 1),
#   ('NLP_s370', 1),
#   ('NLP_s371', 1),
#   ('NLP_s375', 1),
#   ('NLP_s380', 1),
#   ('NLP_s382', 1),
#   ('Image_bbf3', 1),
#   ('Image_bbf5', 1),
#   ('Image_bbf6', 1),
#   ('Image_bbf10', 1),
#   ('Image_mean_brightness', 1),
#   ('Image_hist6', 1),
#   ('Image_hist14', 1),
#   ('Image_hist15', 1),
#   ('Image_hist17', 1),
#   ('Image_hist21', 1),
#   ('Image_hist22', 1),
#   ('Image_hist23', 1),
#   ('Image_hist26', 1),
#   ('Image_hist27', 1),
#   ('Image_hist28', 1),
#   ('Image_hist30', 1),
#   ('Image_hist31', 1),
#   ('Image_hist32', 1),
#   ('Image_hist34', 1),
#   ('Image_hist36', 1),
#   ('Image_hist37', 1),
#   ('Image_hist38', 1),
#   ('Image_hist40', 1),
#   ('Image_hist46', 1),
#   ('Image_hist50', 1),
#   ('Image_hist54', 1),
#   ('Image_hist55', 1),
#   ('Image_hist61', 1),
#   ('Image_hist62', 1),
#   ('Image_hist64', 1),
#   ('Image_hist66', 1),
#   ('Image_hist67', 1),
#   ('Image_hist69', 1),
#   ('Image_hist72', 1),
#   ('Image_hist78', 1),
#   ('Image_hist85', 1),
#   ('Image_hist90', 1),
#   ('Image_hist91', 1),
#   ('Image_hist96', 1),
#   ('Image_hist97', 1),
#   ('Image_hist101', 1),
#   ('Image_hist109', 1),
#   ('Image_hist113', 1),
#   ('Image_hist114', 1),
#   ('Image_hist115', 1),
#   ('Image_hist116', 1),
#   ('Image_hist129', 1),
#   ('Image_hist131', 1),
#   ('Image_hist132', 1),
#   ('Image_hist133', 1),
#   ('Image_hist135', 1),
#   ('Image_hist139', 1),
#   ('Image_hist147', 1),
#   ('Image_hist151', 1),
#   ('Image_hist154', 1),
#   ('Image_hist162', 1),
#   ('Image_hist163', 1),
#   ('Image_hist165', 1),
#   ('Image_hist171', 1),
#   ('Image_hist172', 1),
#   ('Image_hist174', 1),
#   ('Image_hist176', 1),
#   ('Image_hist177', 1),
#   ('Image_hist180', 1),
#   ('Image_hist192', 1),
#   ('Image_hist197', 1),
#   ('Image_hist200', 1),
#   ('Image_hist201', 1),
#   ('Image_hist205', 1),
#   ('Image_hist208', 1),
#   ('Image_hist209', 1),
#   ('Image_hist215', 1),
#   ('Image_hist220', 1),
#   ('Image_hist222', 1),
#   ('Image_hist223', 1),
#   ('Image_hist224', 1),
#   ('Image_hist225', 1),
#   ('Image_hist227', 1),
#   ('Image_hist233', 1),
#   ('Image_hist234', 1),
#   ('Image_hist236', 1),
#   ('Image_hist242', 1),
#   ('Image_hist246', 1),
#   ('Image_hist247', 1),
#   ('Image_hist248', 1),
#   ('Image_hist254', 1),
#   ('Image_hist256', 1),
#   ('Image_hist260', 1),
#   ('Image_hist268', 1),
#   ('Image_hist269', 1),
#   ('Image_hist275', 1),
#   ('Image_hist279', 1),
#   ('Image_hist282', 1),
#   ('Image_hist286', 1),
#   ('Image_hist304', 1),
#   ('Image_hist308', 1),
#   ('Image_hist309', 1),
#   ('Image_hist310', 1),
#   ('Image_hist315', 1),
#   ('Image_hist318', 1),
#   ('Image_hist322', 1),
#   ('Image_hist326', 1),
#   ('Image_hist327', 1),
#   ('Image_hist330', 1),
#   ('Image_hist336', 1),
#   ('Image_hist340', 1),
#   ('Image_hist341', 1),
#   ('Image_hist346', 1),
#   ('Image_hist349', 1),
#   ('Image_hist350', 1),
#   ('Image_hist353', 1),
#   ('Image_hist356', 1),
#   ('Image_hist357', 1),
#   ('Image_hist359', 1),
#   ('Image_hist360', 1),
#   ('Image_hist365', 1),
#   ('Image_hist379', 1),
#   ('Image_hist380', 1),
#   ('Image_hist382', 1),
#   ('Image_hist384', 1),
#   ('Image_hist394', 1),
#   ('Image_hist400', 1),
#   ('Image_hist404', 1),
#   ('Image_hist410', 1),
#   ('Image_hist413', 1),
#   ('Image_hist417', 1),
#   ('Image_hist423', 1),
#   ('Image_hist424', 1),
#   ('Image_hist436', 1),
#   ('Image_hist437', 1),
#   ('Image_hist438', 1),
#   ('Image_hist442', 1),
#   ('Image_hist451', 1),
#   ('Image_hist452', 1),
#   ('Image_hist464', 1),
#   ('Image_hist465', 1),
#   ('Image_hist469', 1),
#   ('Image_hist474', 1),
#   ('Image_hist479', 1),
#   ('Image_hist480', 1),
#   ('Image_hist493', 1),
#   ('Image_hist498', 1),
#   ('Image_hist500', 1),
#   ('Image_hist501', 1),
#   ('Image_hist505', 1),
#   ('Image_hist506', 1),
#   ('Image_hist512', 1),
#   ('Image_truck', 1),
#   ('Image_bench', 1),
#   ('Image_bottle', 1),
#   ('Image_bowl', 1),
#   ('Amenities_apple_tv', 0),
#   ('Amenities_baby_bath', 0),
#   ('Amenities_babysitter_recommendations', 0),
#   ('Amenities_baking_sheet', 0),
#   ('Amenities_balcony', 0),
#   ('Amenities_barbecue_utensils', 0),
#   ('Amenities_bathtub', 0),
#   ('Amenities_beach_access', 0),
#   ('Amenities_beach_essentials', 0),
#   ('Amenities_beachfront', 0),
#   ('Amenities_bedroom_comforts', 0),
#   ('Amenities_bidet', 0),
#   ('Amenities_bikes', 0),
#   ('Amenities_breakfast_bar', 0),
#   ('Amenities_breakfast_table', 0),
#   ('Amenities_building_staff', 0),
#   ('Amenities_cable_tv', 0),
#   ('Amenities_ceiling_fan', 0),
#   ('Amenities_changing_table', 0),
#   ("Amenities_chef's_kitchen", 0),
#   ('Amenities_cleaning_available_during_stay', 0),
#   ('Amenities_cleaning_before_checkout', 0),
#   ('Amenities_conditioner', 0),
#   ('Amenities_crib', 0),
#   ('Amenities_dining_area', 0),
#   ('Amenities_disabled_parking_spot', 0),
#   ('Amenities_dishes_and_silverware', 0),
#   ('Amenities_double_oven', 0),
#   ('Amenities_dryer', 0),
#   ('Amenities_dvd_player', 0),
#   ('Amenities_en_suite_bathroom', 0),
#   ('Amenities_espresso_machine', 0),
#   ('Amenities_ethernet_connection', 0),
#   ('Amenities_fireplace_guards', 0),
#   ('Amenities_formal_dining_area', 0),
#   ('Amenities_full_kitchen', 0),
#   ('Amenities_game_console', 0),
#   ('Amenities_garden', 0),
#   ('Amenities_garden_or_backyard', 0),
#   ('Amenities_gas_oven', 0),
#   ('Amenities_hangers', 0),
#   ('Amenities_heat_lamps', 0),
#   ('Amenities_high_chair', 0),
#   ('Amenities_host_greets_you', 0),
#   ('Amenities_internet', 0),
#   ('Amenities_ironing_board', 0),
#   ('Amenities_jetted_tub', 0),
#   ('Amenities_kayak', 0),
#   ('Amenities_keypad', 0),
#   ('Amenities_kitchenette', 0),
#   ('Amenities_long_term_stays_allowed', 0),
#   ('Amenities_luggage_dropoff_allowed', 0),
#   ('Amenities_office', 0),
#   ('Amenities_outdoor_kitchen', 0),
#   ('Amenities_outdoor_parking', 0),
#   ('Amenities_outdoor_seating', 0),
#   ('Amenities_outlet_covers', 0),
#   ('Amenities_paid_parking_off_premises', 0),
#   ('Amenities_piano', 0),
#   ('Amenities_ping_pong_table', 0),
#   ('Amenities_pocket_wifi', 0),
#   ('Amenities_pool_cover', 0),
#   ('Amenities_pool_table', 0),
#   ('Amenities_portable_fans', 0),
#   ('Amenities_private_gym', 0),
#   ('Amenities_private_living_room', 0),
#   ('Amenities_private_pool', 0),
#   ('Amenities_propane_barbeque', 0),
#   ('Amenities_rain_shower', 0),
#   ('Amenities_resort_access', 0),
#   ('Amenities_room-darkening_shades', 0),
#   ('Amenities_safe', 0),
#   ('Amenities_sauna', 0),
#   ('Amenities_security_system', 0),
#   ('Amenities_shampoo', 0),
#   ('Amenities_shared_gym', 0),
#   ('Amenities_shared_hot_tub', 0),
#   ('Amenities_ski-in/ski-out', 0),
#   ('Amenities_smart_tv', 0),
#   ('Amenities_smoke_alarm', 0),
#   ('Amenities_smoking_allowed', 0),
#   ('Amenities_soaking_tub', 0),
#   ('Amenities_suitable_for_events', 0),
#   ('Amenities_tennis_court', 0),
#   ('Amenities_terrace', 0),
#   ('Amenities_toaster', 0),
#   ('Amenities_walk-in_shower', 0),
#   ('Amenities_waterfront', 0),
#   ('Amenities_window_guards', 0),
#   ('Amenities_wine_cooler', 0),
#   ('Location_cafe_500m_num', 0),
#   ('NLP_.com', 0),
#   ('NLP_1_queen', 0),
#   ('NLP_10th_&_wilshire', 0),
#   ('NLP_2nd_street', 0),
#   ('NLP_3br/2ba', 0),
#   ('NLP_3rd_street', 0),
#   ('NLP_3rd_street_promenade', 0),
#   ('NLP_8.5mi).', 0),
#   ('NLP_abbot_kinney_blvd', 0),
#   ('NLP_abbot_kinney_boulevard', 0),
#   ('NLP_abc', 0),
#   ('NLP_ac', 0),
#   ('NLP_ac_&', 0),
#   ('NLP_ac/heat', 0),
#   ('NLP_ac/heating', 0),
#   ('NLP_acce', 0),
#   ('NLP_air', 0),
#   ('NLP_air_conditioning', 0),
#   ('NLP_airbnb_will_hold', 0),
#   ('NLP_airdna', 0),
#   ('NLP_airport.', 0),
#   ('NLP_al_fresco', 0),
#   ('NLP_alexa', 0),
#   ('NLP_amazon_firestick', 0),
#   ('NLP_amazon_prime', 0),
#   ('NLP_apple', 0),
#   ('NLP_appletv', 0),
#   ('NLP_aquarium_of_the_pacific', 0),
#   ('NLP_arcadia', 0),
#   ('NLP_arclight_cinema', 0),
#   ('NLP_at&t', 0),
#   ('NLP_avalon', 0),
#   ('NLP_backhouse', 0),
#   ('NLP_backyard', 0),
#   ('NLP_banc_of_california_stadium', 0),
#   ('NLP_bank_of_america', 0),
#   ('NLP_bath', 0),
#   ('NLP_bathtub', 0),
#   ('NLP_bbq', 0),
#   ('NLP_beache', 0),
#   ('NLP_beaches_etc.)', 0),
#   ('NLP_beachwood_canyon', 0),
#   ('NLP_bed/2', 0),
#   ('NLP_bel_air', 0),
#   ('NLP_belmont_shore', 0),
#   ('NLP_beverly_center', 0),
#   ('NLP_beverly_hills_&', 0),
#   ('NLP_biola_university', 0),
#   ('NLP_boardwalk', 0),
#   ('NLP_boeing', 0),
#   ...],
#  0.25: [('Amenities_bathrooms_count', 116),
#   ('Location_mean_area_accommodates_price', 114),
#   ('Amenities_property_type_code', 86),
#   ('NLP_s21', 77),
#   ('Amenities_minimum_nights', 67),
#   ('Amenities_amenities_count', 66),
#   ('Location_mean_area_beds_price', 34),
#   ('Location_real_estate', 33),
#   ('NLP_hulu_&_disney+', 29),
#   ('Amenities_bedrooms', 27),
#   ('Amenities_beds', 26),
#   ('Amenities_maximum_nights', 26),
#   ('NLP_s355', 24),
#   ('NLP_s9', 21),
#   ('NLP_s158', 20),
#   ('Location_Santa_Monica_Promenade', 19),
#   ('Image_hist292', 19),
#   ('Location_Norton_Simon_Museum', 18),
#   ('NLP_s91', 18),
#   ('NLP_s196', 18),
#   ('NLP_s5', 17),
#   ('NLP_s24', 17),
#   ('NLP_s254', 17),
#   ('Amenities_dishwasher', 16),
#   ('Amenities_pets_allowed', 16),
#   ('Location_restaurant_num', 16),
#   ('NLP_tcl_chinese_theater_&_dolby_theater', 16),
#   ('NLP_s255', 16),
#   ('Amenities_pool', 15),
#   ('NLP_s166', 15),
#   ('NLP_s172', 15),
#   ('NLP_s175', 15),
#   ('NLP_s293', 15),
#   ('NLP_s304', 15),
#   ('NLP_s307', 15),
#   ('NLP_s352', 15),
#   ('Image_hist75', 15),
#   ('Image_hist228', 15),
#   ('Amenities_outdoor_dining_area', 14),
#   ('NLP_s4', 14),
#   ('NLP_s26', 14),
#   ('NLP_s44', 14),
#   ('NLP_s135', 14),
#   ('NLP_s185', 14),
#   ('NLP_s311', 14),
#   ('NLP_s315', 14),
#   ('Image_bbf1', 14),
#   ('Amenities_room_type_code', 13),
#   ('Location_transport_most_close_dis', 13),
#   ('Location_transport_1000m_num', 13),
#   ('Location_Angeles_Stadium', 13),
#   ('Location_ACMA', 13),
#   ('Location_Los_Angeles_International_Airport', 13),
#   ('NLP_s78', 13),
#   ('NLP_s139', 13),
#   ('NLP_s150', 13),
#   ('NLP_s157', 13),
#   ('NLP_s170', 13),
#   ('NLP_s180', 13),
#   ('NLP_s193', 13),
#   ('NLP_s209', 13),
#   ('NLP_s253', 13),
#   ('NLP_s280', 13),
#   ('NLP_s281', 13),
#   ('NLP_s299', 13),
#   ('Image_hist1', 13),
#   ('Amenities_books_and_reading_material', 12),
#   ('Amenities_first_aid_kit', 12),
#   ('Amenities_free_parking_on_premises', 12),
#   ('Location_California_Science_Center', 12),
#   ('NLP_s66', 12),
#   ('NLP_s85', 12),
#   ('NLP_s116', 12),
#   ('NLP_s159', 12),
#   ('NLP_s163', 12),
#   ('NLP_s165', 12),
#   ('NLP_s225', 12),
#   ('NLP_s275', 12),
#   ('NLP_s287', 12),
#   ('NLP_s292', 12),
#   ('Image_hist438', 12),
#   ('Amenities_bathrooms_type_code', 11),
#   ('Amenities_hot_water_kettle', 11),
#   ('Amenities_indoor_fireplace', 11),
#   ('Location_Universal_Studios_Hollywood', 11),
#   ('Location_Santa_Monica_Pier', 11),
#   ('NLP_s7', 11),
#   ('NLP_s14', 11),
#   ('NLP_s16', 11),
#   ('NLP_s30', 11),
#   ('NLP_s31', 11),
#   ('NLP_s36', 11),
#   ('NLP_s41', 11),
#   ('NLP_s42', 11),
#   ('NLP_s45', 11),
#   ('NLP_s50', 11),
#   ('NLP_s53', 11),
#   ('NLP_s119', 11),
#   ('NLP_s132', 11),
#   ('NLP_s147', 11),
#   ('NLP_s167', 11),
#   ('NLP_s182', 11),
#   ('NLP_s190', 11),
#   ('NLP_s203', 11),
#   ('NLP_s212', 11),
#   ('NLP_s222', 11),
#   ('NLP_s227', 11),
#   ('NLP_s232', 11),
#   ('NLP_s233', 11),
#   ('NLP_s242', 11),
#   ('NLP_s264', 11),
#   ('NLP_s284', 11),
#   ('NLP_s294', 11),
#   ('NLP_s302', 11),
#   ('NLP_s329', 11),
#   ('NLP_s335', 11),
#   ('NLP_s375', 11),
#   ('Amenities_exercise_equipment', 10),
#   ('Amenities_kitchen', 10),
#   ('NLP_boutique_hostel', 10),
#   ('NLP_s18', 10),
#   ('NLP_s19', 10),
#   ('NLP_s35', 10),
#   ('NLP_s43', 10),
#   ('NLP_s47', 10),
#   ('NLP_s51', 10),
#   ('NLP_s73', 10),
#   ('NLP_s87', 10),
#   ('NLP_s92', 10),
#   ('NLP_s107', 10),
#   ('NLP_s151', 10),
#   ('NLP_s156', 10),
#   ('NLP_s181', 10),
#   ('NLP_s201', 10),
#   ('NLP_s204', 10),
#   ('NLP_s208', 10),
#   ('NLP_s220', 10),
#   ('NLP_s224', 10),
#   ('NLP_s239', 10),
#   ('NLP_s257', 10),
#   ('NLP_s273', 10),
#   ('NLP_s285', 10),
#   ('NLP_s288', 10),
#   ('NLP_s295', 10),
#   ('NLP_s306', 10),
#   ('NLP_s309', 10),
#   ('NLP_s324', 10),
#   ('NLP_s332', 10),
#   ('NLP_s334', 10),
#   ('NLP_s337', 10),
#   ('NLP_s339', 10),
#   ('NLP_s366', 10),
#   ('NLP_s367', 10),
#   ('Image_hist156', 10),
#   ('Image_hist238', 10),
#   ('Amenities_air_conditioning', 9),
#   ('Amenities_bbq_grill', 9),
#   ('Amenities_hair_dryer', 9),
#   ('Amenities_microwave', 9),
#   ('Location_cafe_500m_num', 9),
#   ('Location_Venice_Beach', 9),
#   ('Location_Melrose_Avenue', 9),
#   ('Location_Abbot_Kinney_Blvd', 9),
#   ('NLP_s1', 9),
#   ('NLP_s12', 9),
#   ('NLP_s32', 9),
#   ('NLP_s33', 9),
#   ('NLP_s52', 9),
#   ('NLP_s55', 9),
#   ('NLP_s56', 9),
#   ('NLP_s68', 9),
#   ('NLP_s72', 9),
#   ('NLP_s74', 9),
#   ('NLP_s79', 9),
#   ('NLP_s84', 9),
#   ('NLP_s101', 9),
#   ('NLP_s106', 9),
#   ('NLP_s113', 9),
#   ('NLP_s114', 9),
#   ('NLP_s115', 9),
#   ('NLP_s121', 9),
#   ('NLP_s122', 9),
#   ('NLP_s123', 9),
#   ('NLP_s126', 9),
#   ('NLP_s129', 9),
#   ('NLP_s140', 9),
#   ('NLP_s141', 9),
#   ('NLP_s160', 9),
#   ('NLP_s171', 9),
#   ('NLP_s197', 9),
#   ('NLP_s199', 9),
#   ('NLP_s207', 9),
#   ('NLP_s221', 9),
#   ('NLP_s240', 9),
#   ('NLP_s241', 9),
#   ('NLP_s244', 9),
#   ('NLP_s247', 9),
#   ('NLP_s256', 9),
#   ('NLP_s269', 9),
#   ('NLP_s276', 9),
#   ('NLP_s286', 9),
#   ('NLP_s298', 9),
#   ('NLP_s305', 9),
#   ('NLP_s330', 9),
#   ('NLP_s347', 9),
#   ('NLP_s348', 9),
#   ('NLP_s354', 9),
#   ('NLP_s358', 9),
#   ('NLP_s359', 9),
#   ('NLP_s360', 9),
#   ('NLP_s361', 9),
#   ('NLP_s380', 9),
#   ('Image_mean_brightness', 9),
#   ('Image_hist10', 9),
#   ('Image_hist221', 9),
#   ('Image_hist301', 9),
#   ('Image_hist367', 9),
#   ('Image_hist439', 9),
#   ('Image_hist503', 9),
#   ('Amenities_fire_pit', 8),
#   ('Amenities_free_street_parking', 8),
#   ('Location_cafe_500m_dis', 8),
#   ('Location_Hollywood_Walk_of_Fame', 8),
#   ('NLP_s0', 8),
#   ('NLP_s6', 8),
#   ('NLP_s10', 8),
#   ('NLP_s13', 8),
#   ('NLP_s34', 8),
#   ('NLP_s60', 8),
#   ('NLP_s75', 8),
#   ('NLP_s81', 8),
#   ('NLP_s88', 8),
#   ('NLP_s93', 8),
#   ('NLP_s99', 8),
#   ('NLP_s118', 8),
#   ('NLP_s127', 8),
#   ('NLP_s134', 8),
#   ('NLP_s137', 8),
#   ('NLP_s143', 8),
#   ('NLP_s164', 8),
#   ('NLP_s174', 8),
#   ('NLP_s178', 8),
#   ('NLP_s179', 8),
#   ('NLP_s192', 8),
#   ('NLP_s195', 8),
#   ('NLP_s198', 8),
#   ('NLP_s206', 8),
#   ('NLP_s213', 8),
#   ('NLP_s214', 8),
#   ('NLP_s216', 8),
#   ('NLP_s218', 8),
#   ('NLP_s226', 8),
#   ('NLP_s230', 8),
#   ('NLP_s231', 8),
#   ('NLP_s236', 8),
#   ('NLP_s251', 8),
#   ('NLP_s252', 8),
#   ('NLP_s263', 8),
#   ('NLP_s265', 8),
#   ('NLP_s268', 8),
#   ('NLP_s270', 8),
#   ('NLP_s278', 8),
#   ('NLP_s289', 8),
#   ('NLP_s290', 8),
#   ('NLP_s316', 8),
#   ('NLP_s320', 8),
#   ('NLP_s325', 8),
#   ('NLP_s333', 8),
#   ('NLP_s344', 8),
#   ('NLP_s349', 8),
#   ('NLP_s350', 8),
#   ('NLP_s364', 8),
#   ('NLP_s369', 8),
#   ('NLP_s379', 8),
#   ('Image_bbf6', 8),
#   ('Image_num_contours', 8),
#   ('Image_hist9', 8),
#   ('Image_hist229', 8),
#   ('Image_hist294', 8),
#   ('Image_hist358', 8),
#   ('Image_hist366', 8),
#   ('Image_hist375', 8),
#   ('Image_hist431', 8),
#   ('Image_hist447', 8),
#   ('Image_hist502', 8),
#   ('Amenities_elevator', 7),
#   ('Amenities_outdoor_furniture', 7),
#   ('Amenities_paid_parking_on_premises', 7),
#   ('Amenities_tv', 7),
#   ('Location_Rodeo_Drive', 7),
#   ('NLP_s2', 7),
#   ('NLP_s15', 7),
#   ('NLP_s22', 7),
#   ('NLP_s25', 7),
#   ('NLP_s27', 7),
#   ('NLP_s37', 7),
#   ('NLP_s38', 7),
#   ('NLP_s59', 7),
#   ('NLP_s63', 7),
#   ('NLP_s65', 7),
#   ('NLP_s69', 7),
#   ('NLP_s86', 7),
#   ('NLP_s90', 7),
#   ('NLP_s108', 7),
#   ('NLP_s112', 7),
#   ('NLP_s131', 7),
#   ('NLP_s138', 7),
#   ('NLP_s142', 7),
#   ('NLP_s153', 7),
#   ('NLP_s176', 7),
#   ('NLP_s177', 7),
#   ('NLP_s183', 7),
#   ('NLP_s186', 7),
#   ('NLP_s189', 7),
#   ('NLP_s191', 7),
#   ('NLP_s210', 7),
#   ('NLP_s211', 7),
#   ('NLP_s219', 7),
#   ('NLP_s237', 7),
#   ('NLP_s243', 7),
#   ('NLP_s248', 7),
#   ('NLP_s250', 7),
#   ('NLP_s258', 7),
#   ('NLP_s259', 7),
#   ('NLP_s260', 7),
#   ('NLP_s262', 7),
#   ('NLP_s266', 7),
#   ('NLP_s271', 7),
#   ('NLP_s274', 7),
#   ('NLP_s277', 7),
#   ('NLP_s313', 7),
#   ('NLP_s314', 7),
#   ('NLP_s322', 7),
#   ('NLP_s328', 7),
#   ('NLP_s342', 7),
#   ('NLP_s346', 7),
#   ('NLP_s351', 7),
#   ('NLP_s362', 7),
#   ('NLP_s374', 7),
#   ('NLP_s377', 7),
#   ('NLP_s383', 7),
#   ('Image_bbf4', 7),
#   ('Image_sharpness', 7),
#   ('Image_num_edges', 7),
#   ('Image_hist3', 7),
#   ('Image_hist65', 7),
#   ('Image_hist74', 7),
#   ('Image_hist112', 7),
#   ('Image_hist140', 7),
#   ('Image_hist149', 7),
#   ('Image_hist192', 7),
#   ('Image_hist222', 7),
#   ('Image_hist293', 7),
#   ('Image_hist432', 7),
#   ('Image_hist436', 7),
#   ('Image_mean_mean_min_dist_r3', 7),
#   ('Amenities_building_staff', 6),
#   ('Amenities_central_air_conditioning', 6),
#   ('Location_Dodgers_Stadium', 6),
#   ('NLP_s3', 6),
#   ('NLP_s8', 6),
#   ('NLP_s17', 6),
#   ('NLP_s20', 6),
#   ('NLP_s28', 6),
#   ('NLP_s29', 6),
#   ('NLP_s40', 6),
#   ('NLP_s61', 6),
#   ('NLP_s64', 6),
#   ('NLP_s71', 6),
#   ('NLP_s80', 6),
#   ('NLP_s100', 6),
#   ('NLP_s104', 6),
#   ('NLP_s105', 6),
#   ('NLP_s125', 6),
#   ('NLP_s133', 6),
#   ('NLP_s155', 6),
#   ('NLP_s168', 6),
#   ('NLP_s173', 6),
#   ('NLP_s228', 6),
#   ('NLP_s234', 6),
#   ('NLP_s235', 6),
#   ('NLP_s238', 6),
#   ('NLP_s249', 6),
#   ('NLP_s291', 6),
#   ('NLP_s296', 6),
#   ('NLP_s297', 6),
#   ('NLP_s321', 6),
#   ('NLP_s338', 6),
#   ('NLP_s341', 6),
#   ('NLP_s343', 6),
#   ('NLP_s356', 6),
#   ('NLP_s357', 6),
#   ('NLP_s363', 6),
#   ('NLP_s372', 6),
#   ('NLP_s381', 6),
#   ('Image_bbf9', 6),
#   ('Image_size', 6),
#   ('Image_homogeneity', 6),
#   ('Image_energy', 6),
#   ('Image_hist73', 6),
#   ('Image_hist83', 6),
#   ('Image_hist84', 6),
#   ('Image_hist146', 6),
#   ('Image_hist159', 6),
#   ('Image_hist168', 6),
#   ('Image_hist231', 6),
#   ('Image_hist256', 6),
#   ('Image_hist316', 6),
#   ('Image_hist430', 6),
#   ('Image_hist440', 6),
#   ('Image_hist445', 6),
#   ('Image_hist466', 6),
#   ('Image_hist494', 6),
#   ('Image_hist512', 6),
#   ('Amenities_barbecue_utensils', 5),
#   ('Amenities_beach_view', 5),
#   ('Amenities_fire_extinguisher', 5),
#   ('Amenities_iron', 5),
#   ('Amenities_lock_on_bedroom_door', 5),
#   ('Amenities_private_entrance', 5),
#   ('Amenities_wine_glasses', 5),
#   ('Location_transport_500m_num', 5),
#   ('Location_Little_Tokyo', 5),
#   ('NLP_s48', 5),
#   ('NLP_s49', 5),
#   ('NLP_s54', 5),
#   ('NLP_s57', 5),
#   ('NLP_s58', 5),
#   ('NLP_s62', 5),
#   ('NLP_s67', 5),
#   ('NLP_s77', 5),
#   ('NLP_s83', 5),
#   ('NLP_s94', 5),
#   ('NLP_s130', 5),
#   ('NLP_s144', 5),
#   ('NLP_s145', 5),
#   ('NLP_s146', 5),
#   ('NLP_s149', 5),
#   ('NLP_s154', 5),
#   ('NLP_s161', 5),
#   ('NLP_s169', 5),
#   ('NLP_s188', 5),
#   ('NLP_s261', 5),
#   ('NLP_s272', 5),
#   ('NLP_s279', 5),
#   ('NLP_s282', 5),
#   ('NLP_s283', 5),
#   ('NLP_s308', 5),
#   ('NLP_s310', 5),
#   ('NLP_s317', 5),
#   ('NLP_s318', 5),
#   ('NLP_s319', 5),
#   ('NLP_s326', 5),
#   ('NLP_s345', 5),
#   ('NLP_s365', 5),
#   ('NLP_s370', 5),
#   ('NLP_s371', 5),
#   ('NLP_s376', 5),
#   ('NLP_s382', 5),
#   ('Image_bbf3', 5),
#   ('Image_bbf7', 5),
#   ('Image_bbf8', 5),
#   ('Image_hist12', 5),
#   ('Image_hist18', 5),
#   ('Image_hist20', 5),
#   ('Image_hist27', 5),
#   ('Image_hist28', 5),
#   ('Image_hist55', 5),
#   ('Image_hist68', 5),
#   ('Image_hist70', 5),
#   ('Image_hist77', 5),
#   ('Image_hist91', 5),
#   ('Image_hist111', 5),
#   ('Image_hist139', 5),
#   ('Image_hist147', 5),
#   ('Image_hist155', 5),
#   ('Image_hist158', 5),
#   ('Image_hist175', 5),
#   ('Image_hist204', 5),
#   ('Image_hist237', 5),
#   ('Image_hist240', 5),
#   ('Image_hist274', 5),
#   ('Image_hist320', 5),
#   ('Image_hist324', 5),
#   ('Image_hist353', 5),
#   ('Image_hist364', 5),
#   ('Image_hist421', 5),
#   ('Image_hist460', 5),
#   ('Image_hist474', 5),
#   ('Image_hist485', 5),
#   ('Image_hist504', 5),
#   ('Amenities_lockbox', 4),
#   ('Amenities_mini_fridge', 4),
#   ('Amenities_private_pool', 4),
#   ('Amenities_self_check-in', 4),
#   ('Location_Griffith_Observatory', 4),
#   ('Location_Farmers_Market', 4),
#   ('NLP_cozy', 4),
#   ('NLP_s11', 4),
#   ('NLP_s39', 4),
#   ('NLP_s82', 4),
#   ('NLP_s89', 4),
#   ('NLP_s95', 4),
#   ('NLP_s98', 4),
#   ('NLP_s109', 4),
#   ('NLP_s110', 4),
#   ('NLP_s117', 4),
#   ('NLP_s120', 4),
#   ('NLP_s152', 4),
#   ('NLP_s184', 4),
#   ('NLP_s187', 4),
#   ('NLP_s202', 4),
#   ('NLP_s205', 4),
#   ('NLP_s215', 4),
#   ('NLP_s245', 4),
#   ('NLP_s246', 4),
#   ('NLP_s301', 4),
#   ('NLP_s327', 4),
#   ('NLP_s331', 4),
#   ('NLP_s340', 4),
#   ('NLP_s353', 4),
#   ('NLP_s373', 4),
#   ('Image_hist2', 4),
#   ('Image_hist5', 4),
#   ('Image_hist31', 4),
#   ('Image_hist39', 4),
#   ('Image_hist45', 4),
#   ('Image_hist46', 4),
#   ('Image_hist63', 4),
#   ('Image_hist66', 4),
#   ('Image_hist80', 4),
#   ('Image_hist94', 4),
#   ('Image_hist101', 4),
#   ('Image_hist118', 4),
#   ('Image_hist129', 4),
#   ('Image_hist137', 4),
#   ('Image_hist138', 4),
#   ('Image_hist148', 4),
#   ('Image_hist154', 4),
#   ('Image_hist160', 4),
#   ('Image_hist165', 4),
#   ('Image_hist171', 4),
#   ('Image_hist173', 4),
#   ('Image_hist202', 4),
#   ('Image_hist212', 4),
#   ('Image_hist213', 4),
#   ('Image_hist220', 4),
#   ('Image_hist224', 4),
#   ('Image_hist227', 4),
#   ('Image_hist265', 4),
#   ('Image_hist295', 4),
#   ('Image_hist299', 4),
#   ('Image_hist302', 4),
#   ('Image_hist304', 4),
#   ('Image_hist308', 4),
#   ('Image_hist311', 4),
#   ('Image_hist312', 4),
#   ('Image_hist319', 4),
#   ('Image_hist337', 4),
#   ('Image_hist347', 4),
#   ('Image_hist357', 4),
#   ('Image_hist363', 4),
#   ('Image_hist368', 4),
#   ('Image_hist376', 4),
#   ('Image_hist384', 4),
#   ('Image_hist385', 4),
#   ('Image_hist404', 4),
#   ('Image_hist413', 4),
#   ('Image_hist420', 4),
#   ('Image_hist424', 4),
#   ('Image_hist428', 4),
#   ('Image_hist429', 4),
#   ('Image_hist446', 4),
#   ('Image_hist448', 4),
#   ('Image_hist476', 4),
#   ('Image_hist491', 4),
#   ('Image_hist493', 4),
#   ('Image_hist500', 4),
#   ('Image_mean_mean_weighted_min_dist_r3', 4),
#   ('Amenities_bathroom_essentials', 3),
#   ('Amenities_bed_linens', 3),
#   ('Amenities_coffee_maker', 3),
#   ('Amenities_dedicated_workspace', 3),
#   ('Amenities_dishes_and_silverware', 3),
#   ('Amenities_dryer', 3),
#   ('Amenities_heating', 3),
#   ('Amenities_host_greets_you', 3),
#   ('Amenities_hot_water', 3),
#   ('Amenities_keypad', 3),
#   ('Amenities_mountain_view', 3),
#   ('Amenities_outdoor_shower', 3),
#   ('Amenities_pool_table', 3),
#   ('Amenities_private_hot_tub', 3),
#   ('Amenities_shared_hot_tub', 3),
#   ('Location_supermarket_num', 3),
#   ('NLP_cable_tv', 3),
#   ('NLP_roku', 3),
#   ('NLP_s23', 3),
#   ('NLP_s46', 3),
#   ('NLP_s70', 3),
#   ('NLP_s97', 3),
#   ('NLP_s102', 3),
#   ('NLP_s111', 3),
#   ('NLP_s124', 3),
#   ('NLP_s128', 3),
#   ('NLP_s136', 3),
#   ('NLP_s162', 3),
#   ('NLP_s194', 3),
#   ('NLP_s200', 3),
#   ('NLP_s217', 3),
#   ('NLP_s223', 3),
#   ('NLP_s229', 3),
#   ('NLP_s267', 3),
#   ('NLP_s300', 3),
#   ('NLP_s303', 3),
#   ('NLP_s312', 3),
#   ('NLP_s368', 3),
#   ('NLP_s378', 3),
#   ('Image_bbf2', 3),
#   ('Image_bbf5', 3),
#   ('Image_bbf10', 3),
#   ('Image_dissimilarity', 3),
#   ('Image_hist7', 3),
#   ('Image_hist13', 3),
#   ('Image_hist15', 3),
#   ('Image_hist23', 3),
#   ('Image_hist24', 3),
#   ('Image_hist26', 3),
#   ('Image_hist29', 3),
#   ('Image_hist32', 3),
#   ('Image_hist36', 3),
#   ('Image_hist37', 3),
#   ('Image_hist67', 3),
#   ('Image_hist76', 3),
#   ('Image_hist78', 3),
#   ('Image_hist92', 3),
#   ('Image_hist93', 3),
#   ('Image_hist95', 3),
#   ('Image_hist104', 3),
#   ('Image_hist120', 3),
#   ('Image_hist126', 3),
#   ('Image_hist131', 3),
#   ('Image_hist145', 3),
#   ('Image_hist157', 3),
#   ('Image_hist161', 3),
#   ('Image_hist166', 3),
#   ('Image_hist176', 3),
#   ('Image_hist182', 3),
#   ('Image_hist183', 3),
#   ('Image_hist191', 3),
#   ('Image_hist200', 3),
#   ('Image_hist201', 3),
#   ('Image_hist205', 3),
#   ('Image_hist211', 3),
#   ('Image_hist216', 3),
#   ('Image_hist232', 3),
#   ('Image_hist239', 3),
#   ('Image_hist245', 3),
#   ('Image_hist246', 3),
#   ('Image_hist247', 3),
#   ('Image_hist248', 3),
#   ('Image_hist254', 3),
#   ('Image_hist255', 3),
#   ('Image_hist266', 3),
#   ('Image_hist269', 3),
#   ('Image_hist273', 3),
#   ('Image_hist275', 3),
#   ('Image_hist289', 3),
#   ('Image_hist303', 3),
#   ('Image_hist309', 3),
#   ('Image_hist313', 3),
#   ('Image_hist321', 3),
#   ('Image_hist339', 3),
#   ('Image_hist341', 3),
#   ('Image_hist346', 3),
#   ('Image_hist355', 3),
#   ('Image_hist360', 3),
#   ('Image_hist365', 3),
#   ('Image_hist373', 3),
#   ('Image_hist374', 3),
#   ('Image_hist391', 3),
#   ('Image_hist405', 3),
#   ('Image_hist411', 3),
#   ('Image_hist419', 3),
#   ('Image_hist422', 3),
#   ('Image_hist437', 3),
#   ('Image_hist444', 3),
#   ('Image_hist483', 3),
#   ('Image_hist488', 3),
#   ('Image_hist496', 3),
#   ('Image_hist497', 3),
#   ('Image_hist499', 3),
#   ('Image_hist507', 3),
#   ('Image_hist508', 3),
#   ('Amenities_beach_access', 2),
#   ('Amenities_beach_essentials', 2),
#   ('Amenities_bidet', 2),
#   ('Amenities_blender', 2),
#   ('Amenities_body_soap', 2),
#   ('Amenities_bread_maker', 2),
#   ('Amenities_carbon_monoxide_alarm', 2),
#   ('Amenities_cooking_basics', 2),
#   ('Amenities_crib', 2),
#   ('Amenities_essentials', 2),
#   ('Amenities_ev_charger', 2),
#   ('Amenities_high_chair', 2),
#   ('Amenities_luggage_dropoff_allowed', 2),
#   ('Amenities_patio_or_balcony', 2),
#   ('Amenities_shampoo', 2),
#   ('Amenities_single_level_home', 2),
#   ('Amenities_smoke_alarm', 2),
#   ('Amenities_stove', 2),
#   ('Amenities_waterfront', 2),
#   ('Amenities_wifi', 2),
#   ('NLP_disney', 2),
#   ('NLP_long_beach', 2),
#   ('NLP_sawtelle_boulevard', 2),
#   ('NLP_spanish_mediterranean', 2),
#   ('NLP_the_long_beach_convention_center', 2),
#   ('NLP_the_magic_castle', 2),
#   ('NLP_townhouse', 2),
#   ('NLP_s96', 2),
#   ('NLP_s103', 2),
#   ('NLP_s336', 2),
#   ('Image_hist4', 2),
#   ('Image_hist8', 2),
#   ('Image_hist11', 2),
#   ('Image_hist14', 2),
#   ('Image_hist21', 2),
#   ('Image_hist22', 2),
#   ('Image_hist81', 2),
#   ('Image_hist82', 2),
#   ('Image_hist85', 2),
#   ('Image_hist87', 2),
#   ('Image_hist88', 2),
#   ('Image_hist90', 2),
#   ('Image_hist96', 2),
#   ('Image_hist99', 2),
#   ('Image_hist100', 2),
#   ('Image_hist102', 2),
#   ('Image_hist103', 2),
#   ('Image_hist106', 2),
#   ('Image_hist107', 2),
#   ('Image_hist110', 2),
#   ('Image_hist119', 2),
#   ('Image_hist127', 2),
#   ('Image_hist130', 2),
#   ('Image_hist136', 2),
#   ('Image_hist141', 2),
#   ('Image_hist144', 2),
#   ('Image_hist150', 2),
#   ('Image_hist151', 2),
#   ('Image_hist152', 2),
#   ('Image_hist163', 2),
#   ('Image_hist167', 2),
#   ('Image_hist172', 2),
#   ('Image_hist174', 2),
#   ('Image_hist179', 2),
#   ('Image_hist180', 2),
#   ('Image_hist184', 2),
#   ('Image_hist189', 2),
#   ('Image_hist194', 2),
#   ('Image_hist196', 2),
#   ('Image_hist198', 2),
#   ('Image_hist203', 2),
#   ('Image_hist214', 2),
#   ('Image_hist219', 2),
#   ('Image_hist226', 2),
#   ('Image_hist230', 2),
#   ('Image_hist258', 2),
#   ('Image_hist259', 2),
#   ('Image_hist270', 2),
#   ('Image_hist277', 2),
#   ('Image_hist278', 2),
#   ('Image_hist280', 2),
#   ('Image_hist282', 2),
#   ('Image_hist283', 2),
#   ('Image_hist284', 2),
#   ('Image_hist285', 2),
#   ('Image_hist286', 2),
#   ('Image_hist290', 2),
#   ('Image_hist296', 2),
#   ('Image_hist297', 2),
#   ('Image_hist298', 2),
#   ('Image_hist307', 2),
#   ('Image_hist327', 2),
#   ('Image_hist332', 2),
#   ('Image_hist348', 2),
#   ('Image_hist350', 2),
#   ('Image_hist356', 2),
#   ('Image_hist359', 2),
#   ('Image_hist371', 2),
#   ('Image_hist372', 2),
#   ('Image_hist392', 2),
#   ('Image_hist393', 2),
#   ('Image_hist395', 2),
#   ('Image_hist401', 2),
#   ('Image_hist415', 2),
#   ('Image_hist416', 2),
#   ('Image_hist427', 2),
#   ('Image_hist435', 2),
#   ('Image_hist442', 2),
#   ('Image_hist467', 2),
#   ('Image_hist468', 2),
#   ('Image_hist469', 2),
#   ('Image_hist473', 2),
#   ('Image_hist477', 2),
#   ('Image_hist479', 2),
#   ('Image_hist482', 2),
#   ('Image_hist484', 2),
#   ('Image_hist486', 2),
#   ('Image_hist495', 2),
#   ('Image_hist498', 2),
#   ('Image_hist505', 2),
#   ('Image_hist509', 2),
#   ('Image_hist510', 2),
#   ('Image_hist511', 2),
#   ('Image_potted_plant', 2),
#   ('Amenities_baking_sheet', 1),
#   ('Amenities_bathtub', 1),
#   ('Amenities_bikes', 1),
#   ('Amenities_ceiling_fan', 1),
#   ('Amenities_cleaning_products', 1),
#   ('Amenities_coffee', 1),
#   ('Amenities_conditioner', 1),
#   ('Amenities_dining_table', 1),
#   ('Amenities_ethernet_connection', 1),
#   ('Amenities_extra_pillows_and_blankets', 1),
#   ('Amenities_freezer', 1),
#   ('Amenities_gym', 1),
#   ('Amenities_hammock', 1),
#   ('Amenities_hangers', 1),
#   ('Amenities_hot_tub', 1),
#   ('Amenities_long_term_stays_allowed', 1),
#   ('Amenities_mosquito_net', 1),
#   ('Amenities_paid_parking_off_premises', 1),
#   ('Amenities_piano', 1),
#   ('Amenities_pocket_wifi', 1),
#   ('Amenities_portable_fans', 1),
#   ('Amenities_private_living_room', 1),
#   ('Amenities_shared_pool', 1),
#   ('Amenities_smart_lock', 1),
#   ('Amenities_smoking_allowed', 1),
#   ('Amenities_toaster', 1),
#   ('Amenities_washer', 1),
#   ('Amenities_window_guards', 1),
#   ('Location_TCL_Chinese_Theatre', 1),
#   ('NLP_.com', 1),
#   ('NLP_amc', 1),
#   ('NLP_brand', 1),
#   ('NLP_cb', 1),
#   ('NLP_gold_line', 1),
#   ('NLP_keurig', 1),
#   ('NLP_metro', 1),
#   ('NLP_metro_gold_line', 1),
#   ('NLP_mini', 1),
#   ('NLP_nespresso', 1),
#   ('NLP_redondo', 1),
#   ('NLP_rodeo_drive', 1),
#   ('NLP_sono', 1),
#   ('NLP_studio', 1),
#   ('NLP_tesla', 1),
#   ('NLP_the_chinese_theater', 1),
#   ('NLP_the_hollywood_walk_of_fame', 1),
#   ('NLP_usc', 1),
#   ('NLP_washer/dryer', 1),
#   ('NLP_west/east', 1),
#   ('NLP_wi-fi', 1),
#   ('NLP_s76', 1),
#   ('NLP_s148', 1),
#   ('NLP_s323', 1),
#   ('Image_contrast', 1),
#   ('Image_correlation', 1),
#   ('Image_hist6', 1),
#   ('Image_hist16', 1),
#   ('Image_hist19', 1),
#   ('Image_hist30', 1),
#   ('Image_hist35', 1),
#   ('Image_hist38', 1),
#   ('Image_hist40', 1),
#   ('Image_hist41', 1),
#   ('Image_hist44', 1),
#   ('Image_hist54', 1),
#   ('Image_hist60', 1),
#   ('Image_hist62', 1),
#   ('Image_hist71', 1),
#   ('Image_hist72', 1),
#   ('Image_hist79', 1),
#   ('Image_hist89', 1),
#   ('Image_hist108', 1),
#   ('Image_hist109', 1),
#   ('Image_hist124', 1),
#   ('Image_hist125', 1),
#   ('Image_hist128', 1),
#   ('Image_hist132', 1),
#   ('Image_hist133', 1),
#   ('Image_hist135', 1),
#   ('Image_hist142', 1),
#   ('Image_hist143', 1),
#   ('Image_hist153', 1),
#   ('Image_hist164', 1),
#   ('Image_hist178', 1),
#   ('Image_hist190', 1),
#   ('Image_hist193', 1),
#   ('Image_hist195', 1),
#   ('Image_hist206', 1),
#   ('Image_hist208', 1),
#   ('Image_hist210', 1),
#   ('Image_hist217', 1),
#   ('Image_hist223', 1),
#   ('Image_hist225', 1),
#   ('Image_hist233', 1),
#   ('Image_hist235', 1),
#   ('Image_hist236', 1),
#   ('Image_hist244', 1),
#   ('Image_hist249', 1),
#   ('Image_hist252', 1),
#   ('Image_hist253', 1),
#   ('Image_hist262', 1),
#   ('Image_hist264', 1),
#   ('Image_hist267', 1),
#   ('Image_hist276', 1),
#   ('Image_hist279', 1),
#   ('Image_hist281', 1),
#   ('Image_hist287', 1),
#   ('Image_hist291', 1),
#   ('Image_hist300', 1),
#   ('Image_hist305', 1),
#   ('Image_hist306', 1),
#   ('Image_hist310', 1),
#   ('Image_hist317', 1),
#   ('Image_hist318', 1),
#   ('Image_hist323', 1),
#   ('Image_hist329', 1),
#   ('Image_hist334', 1),
#   ('Image_hist335', 1),
#   ('Image_hist340', 1),
#   ('Image_hist342', 1),
#   ('Image_hist345', 1),
#   ('Image_hist349', 1),
#   ('Image_hist351', 1),
#   ('Image_hist354', 1),
#   ('Image_hist377', 1),
#   ('Image_hist379', 1),
#   ('Image_hist381', 1),
#   ('Image_hist382', 1),
#   ('Image_hist388', 1),
#   ('Image_hist396', 1),
#   ('Image_hist397', 1),
#   ('Image_hist399', 1),
#   ('Image_hist403', 1),
#   ('Image_hist406', 1),
#   ('Image_hist408', 1),
#   ('Image_hist425', 1),
#   ('Image_hist426', 1),
#   ('Image_hist450', 1),
#   ('Image_hist457', 1),
#   ('Image_hist458', 1),
#   ('Image_hist459', 1),
#   ('Image_hist461', 1),
#   ('Image_hist462', 1),
#   ('Image_hist463', 1),
#   ('Image_hist470', 1),
#   ('Image_hist475', 1),
#   ('Image_hist481', 1),
#   ('Image_hist487', 1),
#   ('Image_hist492', 1),
#   ('Image_hist501', 1),
#   ('Image_couch', 1),
#   ('Image_oven', 1),
#   ('Image_clock', 1),
#   ('Amenities_apple_tv', 0),
#   ('Amenities_baby_bath', 0),
#   ('Amenities_baby_monitor', 0),
#   ('Amenities_baby_safety_gates', 0),
#   ('Amenities_babysitter_recommendations', 0),
#   ('Amenities_balcony', 0),
#   ('Amenities_beachfront', 0),
#   ('Amenities_bedroom_comforts', 0),
#   ('Amenities_board_games', 0),
#   ('Amenities_breakfast', 0),
#   ('Amenities_breakfast_bar', 0),
#   ('Amenities_breakfast_table', 0),
#   ('Amenities_cable_tv', 0),
#   ('Amenities_changing_table', 0),
#   ("Amenities_chef's_kitchen", 0),
#   ('Amenities_cleaning_available_during_stay', 0),
#   ('Amenities_cleaning_before_checkout', 0),
#   ('Amenities_dining_area', 0),
#   ('Amenities_disabled_parking_spot', 0),
#   ('Amenities_double_oven', 0),
#   ('Amenities_dvd_player', 0),
#   ('Amenities_en_suite_bathroom', 0),
#   ('Amenities_espresso_machine', 0),
#   ('Amenities_fireplace_guards', 0),
#   ('Amenities_formal_dining_area', 0),
#   ('Amenities_full_kitchen', 0),
#   ('Amenities_game_console', 0),
#   ('Amenities_garden', 0),
# ...
#   ('NLP_s340', 7),
#   ('NLP_s344', 7),
#   ('NLP_s345', 7),
#   ('NLP_s353', 7),
#   ('NLP_s381', 7),
#   ('Image_energy', 7),
#   ('Image_hist9', 7),
#   ('Image_hist11', 7),
#   ('Image_hist66', 7),
#   ('Image_hist147', 7),
#   ('Image_hist174', 7),
#   ('Image_hist290', 7),
#   ('Image_hist365', 7),
#   ('Image_hist366', 7),
#   ('Image_hist367', 7),
#   ('Image_hist431', 7),
#   ('Image_hist448', 7),
#   ('Image_hist494', 7),
#   ('Image_hist502', 7),
#   ('Amenities_room_type_code', 6),
#   ('Amenities_building_staff', 6),
#   ('Amenities_ev_charger', 6),
#   ('Amenities_fire_pit', 6),
#   ('Amenities_free_street_parking', 6),
#   ('Amenities_gym', 6),
#   ('Amenities_hammock', 6),
#   ('Amenities_paid_parking_on_premises', 6),
#   ('Amenities_refrigerator', 6),
#   ('Location_California_Science_Center', 6),
#   ('Location_Abbot_Kinney_Blvd', 6),
#   ('NLP_s16', 6),
#   ('NLP_s45', 6),
#   ('NLP_s61', 6),
#   ('NLP_s77', 6),
#   ('NLP_s103', 6),
#   ('NLP_s126', 6),
#   ('NLP_s131', 6),
#   ('NLP_s134', 6),
#   ('NLP_s139', 6),
#   ('NLP_s152', 6),
#   ('NLP_s173', 6),
#   ('NLP_s176', 6),
#   ('NLP_s191', 6),
#   ('NLP_s194', 6),
#   ('NLP_s202', 6),
#   ('NLP_s214', 6),
#   ('NLP_s216', 6),
#   ('NLP_s231', 6),
#   ('NLP_s256', 6),
#   ('NLP_s265', 6),
#   ('NLP_s275', 6),
#   ('NLP_s281', 6),
#   ('NLP_s282', 6),
#   ('NLP_s283', 6),
#   ('NLP_s284', 6),
#   ('NLP_s290', 6),
#   ('NLP_s293', 6),
#   ('NLP_s297', 6),
#   ('NLP_s304', 6),
#   ('NLP_s364', 6),
#   ('NLP_s373', 6),
#   ('Image_bbf7', 6),
#   ('Image_hist8', 6),
#   ('Image_hist12', 6),
#   ('Image_hist30', 6),
#   ('Image_hist76', 6),
#   ('Image_hist95', 6),
#   ('Image_hist137', 6),
#   ('Image_hist152', 6),
#   ('Image_hist168', 6),
#   ('Image_hist229', 6),
#   ('Image_hist274', 6),
#   ('Image_hist295', 6),
#   ('Image_mean_mean_weighted_min_dist_r3', 6),
#   ('Amenities_bathrooms_type_code', 5),
#   ('Amenities_baking_sheet', 5),
#   ('Amenities_dedicated_workspace', 5),
#   ('Amenities_essentials', 5),
#   ('Amenities_first_aid_kit', 5),
#   ('Amenities_hot_tub', 5),
#   ('Amenities_mountain_view', 5),
#   ('Amenities_shower_gel', 5),
#   ('Amenities_sound_system', 5),
#   ('Location_Little_Tokyo', 5),
#   ('Location_ACMA', 5),
#   ('NLP_s4', 5),
#   ('NLP_s28', 5),
#   ('NLP_s65', 5),
#   ('NLP_s76', 5),
#   ('NLP_s102', 5),
#   ('NLP_s109', 5),
#   ('NLP_s110', 5),
#   ('NLP_s144', 5),
#   ('NLP_s145', 5),
#   ('NLP_s166', 5),
#   ('NLP_s175', 5),
#   ('NLP_s186', 5),
#   ('NLP_s193', 5),
#   ('NLP_s198', 5),
#   ('NLP_s199', 5),
#   ('NLP_s230', 5),
#   ('NLP_s234', 5),
#   ('NLP_s238', 5),
#   ('NLP_s280', 5),
#   ('NLP_s289', 5),
#   ('NLP_s295', 5),
#   ('NLP_s302', 5),
#   ('NLP_s309', 5),
#   ('NLP_s366', 5),
#   ('NLP_s368', 5),
#   ('NLP_s369', 5),
#   ('NLP_s375', 5),
#   ('NLP_s377', 5),
#   ('Image_bbf1', 5),
#   ('Image_bbf8', 5),
#   ('Image_contrast', 5),
#   ('Image_hist10', 5),
#   ('Image_hist48', 5),
#   ('Image_hist68', 5),
#   ('Image_hist83', 5),
#   ('Image_hist84', 5),
#   ('Image_hist85', 5),
#   ('Image_hist91', 5),
#   ('Image_hist144', 5),
#   ('Image_hist149', 5),
#   ('Image_hist154', 5),
#   ('Image_hist156', 5),
#   ('Image_hist159', 5),
#   ('Image_hist218', 5),
#   ('Image_hist237', 5),
#   ('Image_hist238', 5),
#   ('Image_hist255', 5),
#   ('Image_hist285', 5),
#   ('Image_hist302', 5),
#   ('Image_hist304', 5),
#   ('Image_hist347', 5),
#   ('Image_hist348', 5),
#   ('Image_hist359', 5),
#   ('Image_hist430', 5),
#   ('Image_hist437', 5),
#   ('Image_hist438', 5),
#   ('Image_hist485', 5),
#   ('Image_hist495', 5),
#   ('Image_person', 5),
#   ('Amenities_bathtub', 4),
#   ('Amenities_breakfast', 4),
#   ('Amenities_ceiling_fan', 4),
#   ('Amenities_crib', 4),
#   ('Amenities_outdoor_kitchen', 4),
#   ('Amenities_piano', 4),
#   ('Amenities_pocket_wifi', 4),
#   ('Amenities_private_entrance', 4),
#   ('Amenities_tv', 4),
#   ('Amenities_wine_glasses', 4),
#   ('Location_cafe_500m_num', 4),
#   ('NLP_main_st.', 4),
#   ('NLP_s15', 4),
#   ('NLP_s89', 4),
#   ('NLP_s118', 4),
#   ('NLP_s123', 4),
#   ('NLP_s124', 4),
#   ('NLP_s146', 4),
#   ('NLP_s150', 4),
#   ('NLP_s165', 4),
#   ('NLP_s184', 4),
#   ('NLP_s201', 4),
#   ('NLP_s246', 4),
#   ('NLP_s254', 4),
#   ('NLP_s257', 4),
#   ('NLP_s301', 4),
#   ('NLP_s317', 4),
#   ('NLP_s334', 4),
#   ('NLP_s354', 4),
#   ('NLP_s361', 4),
#   ('Image_bbf2', 4),
#   ('Image_bbf4', 4),
#   ('Image_dissimilarity', 4),
#   ('Image_num_edges', 4),
#   ('Image_hist4', 4),
#   ('Image_hist15', 4),
#   ('Image_hist18', 4),
#   ('Image_hist46', 4),
#   ('Image_hist71', 4),
#   ('Image_hist73', 4),
#   ('Image_hist75', 4),
#   ('Image_hist81', 4),
#   ('Image_hist93', 4),
#   ('Image_hist119', 4),
#   ('Image_hist131', 4),
#   ('Image_hist142', 4),
#   ('Image_hist146', 4),
#   ('Image_hist158', 4),
#   ('Image_hist166', 4),
#   ('Image_hist202', 4),
#   ('Image_hist214', 4),
#   ('Image_hist216', 4),
#   ('Image_hist221', 4),
#   ('Image_hist222', 4),
#   ('Image_hist224', 4),
#   ('Image_hist232', 4),
#   ('Image_hist246', 4),
#   ('Image_hist273', 4),
#   ('Image_hist310', 4),
#   ('Image_hist320', 4),
#   ('Image_hist351', 4),
#   ('Image_hist364', 4),
#   ('Image_hist376', 4),
#   ('Image_hist383', 4),
#   ('Image_hist410', 4),
#   ('Image_hist421', 4),
#   ('Image_hist422', 4),
#   ('Image_hist428', 4),
#   ('Image_hist429', 4),
#   ('Image_bowl', 4),
#   ('Image_dining_table', 4),
#   ('Amenities_air_conditioning', 3),
#   ('Amenities_barbecue_utensils', 3),
#   ('Amenities_beach_access', 3),
#   ('Amenities_beach_essentials', 3),
#   ('Amenities_blender', 3),
#   ('Amenities_coffee', 3),
#   ('Amenities_iron', 3),
#   ('Amenities_outdoor_shower', 3),
#   ('Amenities_oven', 3),
#   ('Amenities_pets_allowed', 3),
#   ('Amenities_private_living_room', 3),
#   ('Amenities_room-darkening_shades', 3),
#   ('Amenities_single_level_home', 3),
#   ('Amenities_washer', 3),
#   ('Location_transport_1000m_num', 3),
#   ('NLP_hulu_&_disney+', 3),
#   ('NLP_sono', 3),
#   ('NLP_trader_joe’', 3),
#   ('NLP_s170', 3),
#   ('NLP_s321', 3),
#   ('NLP_s371', 3),
#   ('Image_bbf5', 3),
#   ('Image_hist2', 3),
#   ('Image_hist3', 3),
#   ('Image_hist20', 3),
#   ('Image_hist21', 3),
#   ('Image_hist22', 3),
#   ('Image_hist24', 3),
#   ('Image_hist32', 3),
#   ('Image_hist45', 3),
#   ('Image_hist47', 3),
#   ('Image_hist62', 3),
#   ('Image_hist63', 3),
#   ('Image_hist77', 3),
#   ('Image_hist78', 3),
#   ('Image_hist82', 3),
#   ('Image_hist86', 3),
#   ('Image_hist99', 3),
#   ('Image_hist128', 3),
#   ('Image_hist129', 3),
#   ('Image_hist141', 3),
#   ('Image_hist148', 3),
#   ('Image_hist155', 3),
#   ('Image_hist163', 3),
#   ('Image_hist183', 3),
#   ('Image_hist184', 3),
#   ('Image_hist197', 3),
#   ('Image_hist203', 3),
#   ('Image_hist204', 3),
#   ('Image_hist211', 3),
#   ('Image_hist219', 3),
#   ('Image_hist223', 3),
#   ('Image_hist231', 3),
#   ('Image_hist247', 3),
#   ('Image_hist248', 3),
#   ('Image_hist256', 3),
#   ('Image_hist276', 3),
#   ('Image_hist284', 3),
#   ('Image_hist289', 3),
#   ('Image_hist294', 3),
#   ('Image_hist298', 3),
#   ('Image_hist299', 3),
#   ('Image_hist300', 3),
#   ('Image_hist338', 3),
#   ('Image_hist346', 3),
#   ('Image_hist355', 3),
#   ('Image_hist357', 3),
#   ('Image_hist358', 3),
#   ('Image_hist384', 3),
#   ('Image_hist393', 3),
#   ('Image_hist411', 3),
#   ('Image_hist417', 3),
#   ('Image_hist419', 3),
#   ('Image_hist432', 3),
#   ('Image_hist486', 3),
#   ('Image_hist501', 3),
#   ('Image_hist507', 3),
#   ('Image_hist510', 3),
#   ('Image_train', 3),
#   ('Image_bottle', 3),
#   ('Image_chair', 3),
#   ('Image_couch', 3),
#   ('Amenities_bathroom_essentials', 2),
#   ('Amenities_central_air_conditioning', 2),
#   ('Amenities_coffee_maker', 2),
#   ('Amenities_conditioner', 2),
#   ('Amenities_dining_table', 2),
#   ('Amenities_dishes_and_silverware', 2),
#   ('Amenities_fire_extinguisher', 2),
#   ('Amenities_free_parking_on_premises', 2),
#   ('Amenities_heating', 2),
#   ('Amenities_ping_pong_table', 2),
#   ('Amenities_safe', 2),
#   ('Amenities_shampoo', 2),
#   ('Amenities_toaster', 2),
#   ('Location_supermarket_num', 2),
#   ('Location_TCL_Chinese_Theatre', 2),
#   ('Location_Farmers_Market', 2),
#   ('NLP_apple_tv', 2),
#   ('NLP_cal_state', 2),
#   ('NLP_disney_land', 2),
#   ('NLP_gourmet', 2),
#   ('NLP_hollywood_blvd', 2),
#   ('NLP_hrc', 2),
#   ('NLP_jpl', 2),
#   ('NLP_la_landmark', 2),
#   ('NLP_los_angeles.', 2),
#   ('NLP_nespresso', 2),
#   ('NLP_north_hollywood', 2),
#   ('NLP_smart_tv', 2),
#   ('NLP_ucla', 2),
#   ('NLP_s227', 2),
#   ('NLP_s263', 2),
#   ('NLP_s264', 2),
#   ('NLP_s323', 2),
#   ('NLP_s355', 2),
#   ('Image_bbf3', 2),
#   ('Image_bbf10', 2),
#   ('Image_sharpness', 2),
#   ('Image_correlation', 2),
#   ('Image_hist5', 2),
#   ('Image_hist14', 2),
#   ('Image_hist17', 2),
#   ('Image_hist19', 2),
#   ('Image_hist23', 2),
#   ('Image_hist29', 2),
#   ('Image_hist35', 2),
#   ('Image_hist43', 2),
#   ('Image_hist52', 2),
#   ('Image_hist55', 2),
#   ('Image_hist65', 2),
#   ('Image_hist67', 2),
#   ('Image_hist72', 2),
#   ('Image_hist88', 2),
#   ('Image_hist96', 2),
#   ('Image_hist100', 2),
#   ('Image_hist101', 2),
#   ('Image_hist103', 2),
#   ('Image_hist104', 2),
#   ('Image_hist109', 2),
#   ('Image_hist110', 2),
#   ('Image_hist120', 2),
#   ('Image_hist133', 2),
#   ('Image_hist135', 2),
#   ('Image_hist139', 2),
#   ('Image_hist140', 2),
#   ('Image_hist150', 2),
#   ('Image_hist165', 2),
#   ('Image_hist169', 2),
#   ('Image_hist173', 2),
#   ('Image_hist175', 2),
#   ('Image_hist176', 2),
#   ('Image_hist193', 2),
#   ('Image_hist199', 2),
#   ('Image_hist201', 2),
#   ('Image_hist209', 2),
#   ('Image_hist212', 2),
#   ('Image_hist213', 2),
#   ('Image_hist215', 2),
#   ('Image_hist226', 2),
#   ('Image_hist227', 2),
#   ('Image_hist234', 2),
#   ('Image_hist244', 2),
#   ('Image_hist266', 2),
#   ('Image_hist277', 2),
#   ('Image_hist278', 2),
#   ('Image_hist283', 2),
#   ('Image_hist286', 2),
#   ('Image_hist287', 2),
#   ('Image_hist291', 2),
#   ('Image_hist292', 2),
#   ('Image_hist296', 2),
#   ('Image_hist311', 2),
#   ('Image_hist318', 2),
#   ('Image_hist322', 2),
#   ('Image_hist326', 2),
#   ('Image_hist329', 2),
#   ('Image_hist332', 2),
#   ('Image_hist337', 2),
#   ('Image_hist352', 2),
#   ('Image_hist354', 2),
#   ('Image_hist360', 2),
#   ('Image_hist406', 2),
#   ('Image_hist407', 2),
#   ('Image_hist409', 2),
#   ('Image_hist413', 2),
#   ('Image_hist424', 2),
#   ('Image_hist446', 2),
#   ('Image_hist457', 2),
#   ('Image_hist458', 2),
#   ('Image_hist460', 2),
#   ('Image_hist466', 2),
#   ('Image_hist474', 2),
#   ('Image_hist475', 2),
#   ('Image_hist483', 2),
#   ('Image_hist484', 2),
#   ('Image_hist487', 2),
#   ('Image_hist488', 2),
#   ('Image_hist493', 2),
#   ('Image_hist508', 2),
#   ('Image_bird', 2),
#   ('Image_potted_plant', 2),
#   ('Image_book', 2),
#   ('Amenities_baby_bath', 1),
#   ('Amenities_babysitter_recommendations', 1),
#   ('Amenities_bikes', 1),
#   ('Amenities_board_games', 1),
#   ('Amenities_body_soap', 1),
#   ('Amenities_bread_maker', 1),
#   ('Amenities_carbon_monoxide_alarm', 1),
#   ('Amenities_cleaning_available_during_stay', 1),
#   ('Amenities_cleaning_products', 1),
#   ('Amenities_cooking_basics', 1),
#   ('Amenities_dryer', 1),
#   ('Amenities_exercise_equipment', 1),
#   ('Amenities_freezer', 1),
#   ('Amenities_hair_dryer', 1),
#   ('Amenities_hangers', 1),
#   ('Amenities_host_greets_you', 1),
#   ('Amenities_hot_water_kettle', 1),
#   ('Amenities_kitchen', 1),
#   ('Amenities_lockbox', 1),
#   ('Amenities_luggage_dropoff_allowed', 1),
#   ('Amenities_mini_fridge', 1),
#   ('Amenities_patio_or_balcony', 1),
#   ('Amenities_portable_fans', 1),
#   ('Amenities_record_player', 1),
#   ('Amenities_stove', 1),
#   ('Amenities_sun_loungers', 1),
#   ('Amenities_table_corner_guards', 1),
#   ('Amenities_waterfront', 1),
#   ('NLP_3rd_street_promenade', 1),
#   ('NLP_ac/heat', 1),
#   ('NLP_alexa', 1),
#   ('NLP_amazon', 1),
#   ('NLP_apple', 1),
#   ('NLP_arclight_cinema', 1),
#   ('NLP_bosch', 1),
#   ('NLP_burbank_airport', 1),
#   ('NLP_central_hollywood', 1),
#   ('NLP_chinese_theater', 1),
#   ('NLP_costco', 1),
#   ('NLP_dishwasher', 1),
#   ('NLP_fwy', 1),
#   ('NLP_huntington_library', 1),
#   ('NLP_la_live', 1),
#   ('NLP_marina_del_rey', 1),
#   ("NLP_mcdonald'", 1),
#   ('NLP_pacific_ocean', 1),
#   ('NLP_red_metro_line', 1),
#   ('NLP_samsung', 1),
#   ('NLP_santa_monica_mountain', 1),
#   ('NLP_sony', 1),
#   ('NLP_space', 1),
#   ('NLP_staples_center', 1),
#   ('NLP_sunset_blvd', 1),
#   ('NLP_target', 1),
#   ('NLP_the_venice_canal', 1),
#   ('NLP_ventura_blvd', 1),
#   ('NLP_view', 1),
#   ('NLP_weho', 1),
#   ('NLP_wfh', 1),
#   ('Image_hist6', 1),
#   ('Image_hist7', 1),
#   ('Image_hist16', 1),
#   ('Image_hist28', 1),
#   ('Image_hist31', 1),
#   ('Image_hist33', 1),
#   ('Image_hist34', 1),
#   ('Image_hist36', 1),
#   ('Image_hist38', 1),
#   ('Image_hist39', 1),
#   ('Image_hist64', 1),
#   ('Image_hist79', 1),
#   ('Image_hist80', 1),
#   ('Image_hist87', 1),
#   ('Image_hist90', 1),
#   ('Image_hist92', 1),
#   ('Image_hist94', 1),
#   ('Image_hist97', 1),
#   ('Image_hist106', 1),
#   ('Image_hist108', 1),
#   ('Image_hist112', 1),
#   ('Image_hist115', 1),
#   ('Image_hist117', 1),
#   ('Image_hist118', 1),
#   ('Image_hist121', 1),
#   ('Image_hist125', 1),
#   ('Image_hist126', 1),
#   ('Image_hist130', 1),
#   ('Image_hist132', 1),
#   ('Image_hist138', 1),
#   ('Image_hist143', 1),
#   ('Image_hist151', 1),
#   ('Image_hist160', 1),
#   ('Image_hist161', 1),
#   ('Image_hist162', 1),
#   ('Image_hist164', 1),
#   ('Image_hist167', 1),
#   ('Image_hist170', 1),
#   ('Image_hist172', 1),
#   ('Image_hist180', 1),
#   ('Image_hist182', 1),
#   ('Image_hist188', 1),
#   ('Image_hist190', 1),
#   ('Image_hist191', 1),
#   ('Image_hist192', 1),
#   ('Image_hist195', 1),
#   ('Image_hist196', 1),
#   ('Image_hist205', 1),
#   ('Image_hist206', 1),
#   ('Image_hist207', 1),
#   ('Image_hist210', 1),
#   ('Image_hist217', 1),
#   ('Image_hist225', 1),
#   ('Image_hist235', 1),
#   ('Image_hist239', 1),
#   ('Image_hist250', 1),
#   ('Image_hist254', 1),
#   ('Image_hist258', 1),
#   ('Image_hist259', 1),
#   ('Image_hist271', 1),
#   ('Image_hist272', 1),
#   ('Image_hist275', 1),
#   ('Image_hist281', 1),
#   ('Image_hist288', 1),
#   ('Image_hist297', 1),
#   ('Image_hist306', 1),
#   ('Image_hist309', 1),
#   ('Image_hist312', 1),
#   ('Image_hist313', 1),
#   ('Image_hist321', 1),
#   ('Image_hist327', 1),
#   ('Image_hist331', 1),
#   ('Image_hist336', 1),
#   ('Image_hist342', 1),
#   ('Image_hist343', 1),
#   ('Image_hist349', 1),
#   ('Image_hist353', 1),
#   ('Image_hist356', 1),
#   ('Image_hist361', 1),
#   ('Image_hist362', 1),
#   ('Image_hist363', 1),
#   ('Image_hist370', 1),
#   ('Image_hist371', 1),
#   ('Image_hist377', 1),
#   ('Image_hist382', 1),
#   ('Image_hist385', 1),
#   ('Image_hist387', 1),
#   ('Image_hist388', 1),
#   ('Image_hist389', 1),
#   ('Image_hist391', 1),
#   ('Image_hist392', 1),
#   ('Image_hist394', 1),
#   ('Image_hist395', 1),
#   ('Image_hist400', 1),
#   ('Image_hist401', 1),
#   ('Image_hist403', 1),
#   ('Image_hist405', 1),
#   ('Image_hist408', 1),
#   ('Image_hist414', 1),
#   ('Image_hist418', 1),
#   ('Image_hist420', 1),
#   ('Image_hist423', 1),
#   ('Image_hist425', 1),
#   ('Image_hist426', 1),
#   ('Image_hist435', 1),
#   ('Image_hist436', 1),
#   ('Image_hist445', 1),
#   ('Image_hist449', 1),
#   ('Image_hist451', 1),
#   ('Image_hist453', 1),
#   ('Image_hist465', 1),
#   ('Image_hist470', 1),
#   ('Image_hist477', 1),
#   ('Image_hist480', 1),
#   ('Image_hist482', 1),
#   ('Image_hist489', 1),
#   ('Image_hist490', 1),
#   ('Image_hist491', 1),
#   ('Image_hist492', 1),
#   ('Image_hist506', 1),
#   ('Image_bench', 1),
#   ('Image_tv', 1),
#   ('Image_sink', 1),
#   ('Amenities_apple_tv', 0),
#   ('Amenities_baby_monitor', 0),
#   ('Amenities_baby_safety_gates', 0),
#   ('Amenities_balcony', 0),
#   ('Amenities_beachfront', 0),
#   ('Amenities_bed_linens', 0),
#   ('Amenities_bedroom_comforts', 0),
#   ('Amenities_bidet', 0),
#   ('Amenities_breakfast_bar', 0),
#   ('Amenities_breakfast_table', 0),
#   ('Amenities_cable_tv', 0),
#   ('Amenities_changing_table', 0),
#   ("Amenities_chef's_kitchen", 0),
#   ('Amenities_cleaning_before_checkout', 0),
#   ('Amenities_dining_area', 0),
#   ('Amenities_disabled_parking_spot', 0),
#   ('Amenities_double_oven', 0),
#   ('Amenities_dvd_player', 0),
#   ('Amenities_elevator', 0),
#   ('Amenities_en_suite_bathroom', 0),
#   ('Amenities_espresso_machine', 0),
#   ('Amenities_ethernet_connection', 0),
#   ('Amenities_extra_pillows_and_blankets', 0),
#   ('Amenities_fireplace_guards', 0),
#   ('Amenities_formal_dining_area', 0),
#   ('Amenities_full_kitchen', 0),
#   ('Amenities_game_console', 0),
#   ('Amenities_garden', 0),
#   ('Amenities_garden_or_backyard', 0),
#   ('Amenities_gas_oven', 0),
#   ('Amenities_heat_lamps', 0),
#   ('Amenities_high_chair', 0),
#   ('Amenities_hot_water', 0),
#   ('Amenities_internet', 0),
#   ('Amenities_ironing_board', 0),
#   ('Amenities_jetted_tub', 0),
#   ...]}

# %%
pickle.dump(feature_importance_dict, open('Feature_importance_best_models_tuned_raw_features.pkl', 'wb'))

# %%
cv_results = pickle.load(open('Feature_Importance_tuning_raw_feature_cv_results.pkl','rb'))

# %%
cv_list = []
for q in list(model.grid_search_dict.keys()):
    df = pd.DataFrame(model.grid_search_dict[q].cv_results_)
    df['quantile'] = q
    cv_list.append(df)
cv_df = pd.concat(cv_list)

# %%
cv_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_model__learning_rate  ...  \
# 0       96.965366      1.187508        35.444568        0.862262                       0.05  ...
# 1       91.380604      2.124902        32.490757        2.791599                       0.05  ...
# 2       85.670443      3.577855        33.182628        1.072194                       0.05  ...
# 3       86.535251      1.280136        33.661026        0.607365                       0.05  ...
# 4       96.820449      1.267528        33.377338        0.662668                       0.05  ...
# ..            ...           ...              ...             ...                        ...  ...
# 43      95.473408      2.185573        33.632637        0.568856                        0.2  ...
# 44      92.551192      5.092576        32.180233        1.605049                        0.2  ...
# 45      90.277786      2.576923        32.261571        2.913026                        0.2  ...
# 46      92.202851      5.222686        33.511101        2.697780                        0.2  ...
# 47      95.185542      2.006332        24.384477        3.519533                        0.2  ...
#
#    split2_test_neg_mean_squared_error mean_test_neg_mean_squared_error std_test_neg_mean_squared_error  \
# 0                       -15068.820462                    -15012.164474                      112.474696
# 1                       -14826.992277                    -14941.204262                      144.551669
# 2                       -14826.992277                    -14941.204262                      144.551669
# 3                       -14826.992277                    -14941.204262                      144.551669
# 4                       -15349.240581                    -15514.453015                      153.907455
# ..                                ...                              ...                             ...
# 43                      -14073.124719                    -14309.824805                      356.426658
# 44                      -15157.140086                    -14919.890465                      277.370680
# 45                      -15015.897146                    -14751.274797                      200.399995
# 46                      -14829.933953                    -14433.931411                      310.110076
# 47                      -14234.840113                    -14176.129916                      138.545018
#
#     rank_test_neg_mean_squared_error  quantile
# 0                                 39      0.05
# 1                                 36      0.05
# 2                                 36      0.05
# 3                                 36      0.05
# 4                                 43      0.05
# ..                               ...       ...
# 43                                 2      0.95
# 44                                 7      0.95
# 45                                 5      0.95
# 46                                 3      0.95
# 47                                 1      0.95
#
# [240 rows x 33 columns]

# %%
cv_df.sort_values(by=['quantile','mean_test_neg_mean_squared_error'], ascending=[True,False])\
    .to_csv('GridSearch_results_raw_data.csv',index=False)

# %%
len(model.grid_search_dict[0.5].best_estimator_['model'].feature_name_), len(model.grid_search_dict[0.5].best_estimator_['model'].feature_importances_)
# Out:
# (1810, 1810)

# %%
df = pd.read_csv('../../Data/LA_Airbnb/listings_detailed.csv')

# %%
prohibitedWords = ['private', 'shared', ' in ', 'entire', 'room'] # added spaces in front and behind 'in' to ensure accuracy
big_regex = re.compile('|'.join(map(re.escape, prohibitedWords)))
df['property_type_clean'] =  df['property_type'].apply(lambda x: big_regex.sub("", x).strip())
df['property_type_clean'] = np.where(df['property_type_clean']=='',df['room_type'],df['property_type_clean'])

# %%
from collections import Counter
a=Counter()
a.update(df['property_type_clean'].values)
sorted_property_types = sorted(a.items(), key=lambda x:-x[1])
all_sum = np.nansum([i[1] for i in sorted_property_types])
sorted_property_types = [(a,float(b)/all_sum) for a,b in sorted_property_types]
pickle.dump(sorted_property_types, open(f'./utiles/sorted_property_types.pkl','wb'))

# %%
a=Counter()
a.update(df['room_type'].values)
sorted_room_types = sorted(a.items(), key=lambda x:-x[1])
all_sum = np.nansum([i[1] for i in sorted_room_types])
sorted_room_types = [(a,float(b)/all_sum) for a,b in sorted_room_types]
pickle.dump(sorted_room_types, open(f'./utiles/sorted_room_types.pkl','wb'))

# %%
a_u = open(r"./utiles/amenities_universe.txt", "r",encoding='unicode escape').read().split('\n')
bb = pd.read_csv('./final_features/LA_extracted_all_features_imputed.csv')
bb = bb[[i for i in bb.columns if 'Amenities' in i]]
bb.columns = [i.split('Amenities_')[1] for i in bb.columns]
bb = sorted(
    dict(bb[[i for i in bb.columns if i in a_u]].sum(axis=0)).items(),key=lambda x:-x[1]
)
all_sum = np.nansum([i[1] for i in bb])
bb = [(a,float(b)/all_sum) for a,b in bb]
pickle.dump(bb, open(f'./utiles/sorted_amenities.pkl','wb'))
