# %%
import requests
from bs4 import BeautifulSoup
from soup2dict import convert
import pandas as pd
import numpy as np
import os
import time
from tqdm import tqdm

# %%
listings = pd.read_csv('LA_Airbnb/listings_detailed.csv')

# %%
room_codes = [i.split('/')[-1] for i in listings['listing_url'].values]

# %%
def scrape_photos(room_code):
    #### request
    room_urls = f'https://www.airbnb.com/rooms/{room_code}'
    a = requests.get(room_urls)
    time.sleep(2)

    #### get urls
    soup = BeautifulSoup(a.text, 'html.parser')
    b = convert(soup)
    d = b['html'][0]['body'][0]['script'][2]['#text'].split('PHOTO_TOUR_SCROLLABLE"')[1]

    import re
    #### parse urls
    all_urls_found = re.findall(r"(http.*?(jpeg|jpg))",d)

    ### clean urls
    all_url_list= []
    for i in all_urls_found:
        if 'picture' in i[0]:
            all_url_list.append(i[0])
    
    if not os.path.exists(f'./LA_photos/{room_code}'):
        os.mkdir(f'./LA_photos/{room_code}')
    
    
    donwloaded = 0
    for index,url in enumerate(all_url_list[:5]):
        # import cv2
        a = requests.get(url)
        # cv2.imwrite(f'./Boston_photos/{room_code}/{room_code}_{index}.jpg',a.content)

        with open(f'./LA_photos/{room_code}/{room_code}_{index}.jpg', 'wb') as f:
            f.write(a.content)
            donwloaded+=1

    time.sleep(1)
    return donwloaded

# %%
for count,room_code in tqdm(enumerate(room_codes)):
    if count<2330:
        continue
    def dd(room_code):
        donwloaded = 0
        try:
            donwloaded = scrape_photos(room_code) 
        except Exception as e:
            # print(room_code, e)
            pass
        return donwloaded
        
    donwloaded = dd(room_code)
    if donwloaded<5: ### try again if download fail
        donwloaded = dd(room_code)

    if count>3000:
        break
# Out:
# 3001it [3:25:05,  4.10s/it]

# %%
room_code = room_codes[0]

# %%
room_urls = f'https://www.airbnb.com/rooms/{room_code}'
a = requests.get(room_urls)
time.sleep(0.5)

#### get urls
soup = BeautifulSoup(a.text, 'html.parser')
b = convert(soup)
d = b['html'][0]['body'][0]['script'][2]['#text'].split('PHOTO_TOUR_SCROLLABLE"')[1]

import re
#### parse urls
all_urls_found = re.findall(r"(http.*?(jpeg|jpg))",d)

### clean urls
all_url_list= []
for i in all_urls_found:
    if 'picture' in i[0]:
        all_url_list.append(i[0])

# %%
all_url_list
# Out:
# ['https://a0.muscache.com/pictures/24670/b2de0442_original.jpg',
#  'https://a0.muscache.com/pictures/24672/da274cfc_original.jpg',
#  'https://a0.muscache.com/pictures/24674/42b0c05b_original.jpg',
#  'https://a0.muscache.com/pictures/84445/76280d61_original.jpg',
#  'https://a0.muscache.com/pictures/84442/d4affa16_original.jpg',
#  'https://a0.muscache.com/pictures/84444/435c0f41_original.jpg',
#  'https://a0.muscache.com/pictures/ae3d13b5-8d8d-4f23-b363-704c1fdb905c.jpg',
#  'https://a0.muscache.com/pictures/ac225a81-8896-4360-b113-9522472ccd57.jpg',
#  'https://z1.muscache.cn/pictures/42f1a151-d86c-4cad-8e6f-25b5f63cdfd1.jpg',
#  'https://z1.muscache.cn/pictures/899b74cb-ac71-4670-9949-6c78f4c5b903.jpg',
#  'https://z1.muscache.cn/pictures/5ab8181b-a35d-4642-8a85-a50aa0523e96.jpg',
#  'https://z1.muscache.cn/pictures/def98011-ba8e-4eb1-ab3b-24842fc873eb.jpg',
#  'https://z1.muscache.cn/pictures/a0d03019-0313-4526-8c87-cfac2d35f040.jpg',
#  'https://z1.muscache.cn/pictures/bc1ec0c5-f08b-49e1-b24b-d627ad1e0e83.jpg',
#  'https://z1.muscache.cn/pictures/2b4e560c-b7f6-4776-983d-b8a61baa0721.jpg',
#  'https://z1.muscache.cn/pictures/ed743b1d-717c-40ff-91bb-db42e9646a7f.jpg',
#  'https://z1.muscache.cn/pictures/29a80d99-6853-4888-a31a-001c37a78837.jpg']

# %%
d
# Out:
# ',"sectionContentStatus":"COMPLETE","sectionId":"PHOTO_TOUR_SCROLLABLE_MODAL","errors":null,"sectionDependencies":null,"enableDependencies":null,"disableDependencies":null,"loggingData":null,"e2eLoggingSession":null,"mutationMetadata":null,"pluginPointId":null,"section":{"__typename":"PhotoTourModalSection","title":null,"mediaItems":[{"__typename":"Image","id":"201030","accessibilityLabel":"Queen sized bed with  quality mattress","aspectRatio":1.3333333333333333,"baseUrl":"https://a0.muscache.com/pictures/24670/b2de0442_original.jpg","displayAspectRatio":null,"previewEncodedPng":"iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//AamptPn57snT1g4NDfv9/gFyisYgDd3k6N4SERD/AAEBjJGlBPzn9/TrExYR+fsBAXZxaBgYFg4QEgIA+Oju+VNbH2CZkRudAAAAAElFTkSuQmCC","imageMetadata":{"__typename":"ImageMetadata","localizedCaption":null,"caption":"Queen sized bed with  quality mattress","isProfessional":false}},{"__typename":"Image","id":"201031","accessibilityLabel":"Street view, parking to left of house, harbor at end of street","aspectRatio":1.3333333333333333,"baseUrl":"https://a0.muscache.com/pictures/24672/da274cfc_original.jpg","displayAspectRatio":null,"previewEncodedPng":"iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//AcPHyQUDBN7T0j9GRPb08wG5vL3//f22oqIUFxQmMzUBh4mMDw4JxcG/EBARFxQPAVdQTDQzMPX5/Pr8/vn6+9vaH0f+d8sGAAAAAElFTkSuQmCC","imageMetadata":{"__typename":"ImageMetadata","localizedCaption":null,"caption":"Street view, parking to left of house, harbor at end of street","isProfessional":false}},{"__typename":"Image","id":"201033","accessibilityLabel":"Walkway in neighborhood Harborwalk Park","aspectRatio":1.3333333333333333,"baseUrl":"https://a0.muscache.com/pictures/24674/42b0c05b_original.jpg","displayAspectRatio":null,"previewEncodedPng":"iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//AdHW2woIBgkIBgkICejq6wE7QUMIBwQqJyYUEhLZ3NwBSU5LLSgkFBQUCAYJAP79AZSWlvn39PPv6AoKDQQEBm2bFOUaW04DAAAAAElFTkSuQmCC","imageMetadata":{"__typename":"ImageMetadata","localizedCaption":null,"caption":"Walkway in neighborhood Harborwalk Park","isProfessional":false}},{"__typename":"Image","id":"201034","accessibilityLabel":"Boats in harbor as seen from neighborhood","aspectRatio":0.75,"baseUrl":"https://a0.muscache.com/pictures/84445/76280d61_original.jpg","displayAspectRatio":null,"previewEncodedPng":"iVBORw0KGgoAAAANSUhEUgAAAAQAAAAFCAIAAADtz9qMAAAATElEQVQIHQFBAL7/Ae/w8P3/AAABAQIBAQHe4uH8/fwBAQMEBAMBpaal+PPz//T3DBsZAa+ysNrQzgkBAf4KDAGSi20LER/5+wX48u/hzB60IlI63gAAAABJRU5ErkJggg==","imageMetadata":{"__typename":"ImageMetadata","localizedCaption":null,"caption":"Boats in harbor as seen from neighborhood","isProfessional":false}},{"__typename":"Image","id":"201035","accessibilityLabel":"Neighborhood view","aspectRatio":1.3333333333333333,"baseUrl":"https://a0.muscache.com/pictures/84442/d4affa16_original.jpg","displayAspectRatio":null,"previewEncodedPng":"iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//Af3+/vz8/v7//ubo7P8CBAGNkZQCAgMgJivu6+kJCwwBKiwiEhQUCggL8PLy/f36AWlnXxMRD/X09f37+/P19WQuImHLNsuyAAAAAElFTkSuQmCC","imageMetadata":{"__typename":"ImageMetadata","localizedCaption":null,"caption":"Neighborhood view","isProfessional":false}},{"__typename":"Image","id":"201036","accessibilityLabel":"Neighborhood view","aspectRatio":1.3333333333333333,"baseUrl":"https://a0.muscache.com/pictures/84444/435c0f41_original.jpg","displayAspectRatio":null,"previewEncodedPng":"iVBORw0KGgoAAAANSUhEUgAAAAUAAAAECAIAAADJUWIXAAAAS0lEQVQIHQFAAL//Ad7j6QsODO/1+wQBAPT5/QGOjIgIBP3w+OwHChD9ARIBfXtmv9C9DwkPGw4X7O77AZeIdbrDu/b98/wC/QQI/+eQH/CGFR2GAAAAAElFTkSuQmCC","imageMetadata":{"__typename":"ImageMetadata","localizedCaption":null,"caption":"Neighborhood view","isProfessional":false}},{"__typename":"Image","id":"105409367","accessibilityLabel":"Bedroom","aspectRatio":1.7774480712166172,"baseUrl":"https://a0.muscache.com/pictures/ae3d13b5-8d8d-4f23-b363-704c1fdb905c.jpg","displayAspectRatio":null,"previewEncodedPng":"iVBORw0KGgoAAAAN ...
